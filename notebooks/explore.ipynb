# %% [markdown]
# # Explore

# %%
from datasets import list_datasets, load_dataset, list_metrics, load_metric
import spacy
from elasticsearch import Elasticsearch
from datetime import datetime
from tqdm import tqdm

# %%
#!pip install datasets
#!pip install spacy
#!pip install elasticsearch[async]

# %%
list_datasets()
# Out:
# ['acronym_identification',
#  'ade_corpus_v2',
#  'aeslc',
#  'afrikaans_ner_corpus',
#  'ag_news',
#  'ai2_arc',
#  'air_dialogue',
#  'ajgt_twitter_ar',
#  'allegro_reviews',
#  'allocine',
#  'alt',
#  'amazon_polarity',
#  'amazon_reviews_multi',
#  'amazon_us_reviews',
#  'ambig_qa',
#  'amttl',
#  'anli',
#  'app_reviews',
#  'aqua_rat',
#  'aquamuse',
#  'ar_cov19',
#  'ar_res_reviews',
#  'arabic_billion_words',
#  'arabic_pos_dialect',
#  'arcd',
#  'arsentd_lev',
#  'art',
#  'arxiv_dataset',
#  'aslg_pc12',
#  'asnq',
#  'asset',
#  'assin',
#  'assin2',
#  'atomic',
#  'autshumato',
#  'bc2gm_corpus',
#  'best2009',
#  'bianet',
#  'bible_para',
#  'big_patent',
#  'billsum',
#  'bing_coronavirus_query_set',
#  'biomrc',
#  'blended_skill_talk',
#  'blimp',
#  'blog_authorship_corpus',
#  'bookcorpus',
#  'bookcorpusopen',
#  'boolq',
#  'bprec',
#  'break_data',
#  'brwac',
#  'bsd_ja_en',
#  'bswac',
#  'c3',
#  'c4',
#  'cail2018',
#  'capes',
#  'catalonia_independence',
#  'cawac',
#  'cc100',
#  'cdsc',
#  'cdt',
#  'cfq',
#  'chr_en',
#  'cifar10',
#  'circa',
#  'civil_comments',
#  'clickbait_news_bg',
#  'climate_fever',
#  'clinc_oos',
#  'clue',
#  'cmrc2018',
#  'cnn_dailymail',
#  'coached_conv_pref',
#  'coarse_discourse',
#  'codah',
#  'code_search_net',
#  'com_qa',
#  'common_gen',
#  'commonsense_qa',
#  'compguesswhat',
#  'conceptnet5',
#  'conll2000',
#  'conll2002',
#  'conll2003',
#  'conv_ai',
#  'conv_ai_2',
#  'conv_ai_3',
#  'coqa',
#  'cornell_movie_dialog',
#  'cos_e',
#  'cosmos_qa',
#  'counter',
#  'covid_qa_castorini',
#  'covid_qa_deepset',
#  'covid_qa_ucsd',
#  'covid_tweets_japanese',
#  'craigslist_bargains',
#  'crawl_domain',
#  'crd3',
#  'crime_and_punish',
#  'crows_pairs',
#  'cs_restaurants',
#  'csv',
#  'curiosity_dialogs',
#  'daily_dialog',
#  'dane',
#  'danish_political_comments',
#  'dart',
#  'datacommons_factcheck',
#  'dbpedia_14',
#  'dbrd',
#  'deal_or_no_dialog',
#  'definite_pronoun_resolution',
#  'dengue_filipino',
#  'dialog_re',
#  'diplomacy_detection',
#  'disaster_response_messages',
#  'discofuse',
#  'discovery',
#  'doc2dial',
#  'docred',
#  'doqa',
#  'dream',
#  'drop',
#  'dutch_social',
#  'dyk',
#  'e2e_nlg',
#  'e2e_nlg_cleaned',
#  'ecb',
#  'ehealth_kd',
#  'eitb_parcc',
#  'eli5',
#  'emea',
#  'emo',
#  'emotion',
#  'emotone_ar',
#  'empathetic_dialogues',
#  'enriched_web_nlg',
#  'eraser_multi_rc',
#  'esnli',
#  'eth_py150_open',
#  'ethos',
#  'euronews',
#  'europa_eac_tm',
#  'europa_ecdc_tm',
#  'event2Mind',
#  'evidence_infer_treatment',
#  'exams',
#  'factckbr',
#  'fake_news_english',
#  'fake_news_filipino',
#  'farsi_news',
#  'fever',
#  'finer',
#  'flores',
#  'flue',
#  'fquad',
#  'gap',
#  'generated_reviews_enth',
#  'generics_kb',
#  'german_legal_entity_recognition',
#  'germaner',
#  'germeval_14',
#  'giga_fren',
#  'gigaword',
#  'glucose',
#  'glue',
#  'gnad10',
#  'go_emotions',
#  'google_wellformed_query',
#  'grail_qa',
#  'great_code',
#  'guardian_authorship',
#  'gutenberg_time',
#  'hans',
#  'hansards',
#  'hard',
#  'harem',
#  'has_part',
#  'hate_offensive',
#  'hate_speech18',
#  'hate_speech_filipino',
#  'hate_speech_offensive',
#  'hate_speech_pl',
#  'hate_speech_portuguese',
#  'hausa_voa_ner',
#  'hausa_voa_topics',
#  'head_qa',
#  'health_fact',
#  'hebrew_projectbenyehuda',
#  'hebrew_sentiment',
#  'hebrew_this_world',
#  'hellaswag',
#  'hind_encorp',
#  'hindi_discourse',
#  'hippocorpus',
#  'hkcancor',
#  'hope_edi',
#  'hotpot_qa',
#  'hover',
#  'hrenwac_para',
#  'hrwac',
#  'humicroedit',
#  'hybrid_qa',
#  'hyperpartisan_news_detection',
#  'id_clickbait',
#  'id_nergrit_corpus',
#  'id_newspapers_2018',
#  'id_panl_bppt',
#  'igbo_english_machine_translation',
#  'igbo_monolingual',
#  'igbo_ner',
#  'ilist',
#  'imdb',
#  'imdb_urdu_reviews',
#  'imppres',
#  'indic_glue',
#  'indonlu',
#  'inquisitive_qg',
#  'interpress_news_category_tr',
#  'isixhosa_ner_corpus',
#  'isizulu_ner_corpus',
#  'iwslt2017',
#  'jeopardy',
#  'jfleg',
#  'jigsaw_toxicity_pred',
#  'jnlpba',
#  'journalists_questions',
#  'json',
#  'kannada_news',
#  'kd_conv',
#  'kde4',
#  'kelm',
#  'kilt_tasks',
#  'kilt_wikipedia',
#  'kinnews_kirnews',
#  'kor_hate',
#  'kor_ner',
#  'kor_nli',
#  'kor_nlu',
#  'kor_qpair',
#  'kor_sarcasm',
#  'labr',
#  'lama',
#  'lambada',
#  'large_spanish_corpus',
#  'lc_quad',
#  'lener_br',
#  'liar',
#  'librispeech_lm',
#  'limit',
#  'lince',
#  'linnaeus',
#  'liveqa',
#  'lm1b',
#  'lst20',
#  'mac_morpho',
#  'makhzan',
#  'math_dataset',
#  'math_qa',
#  'matinf',
#  'mc_taco',
#  'md_gender_bias',
#  'med_hop',
#  'medal',
#  'medical_dialog',
#  'medical_questions_pairs',
#  'menyo20k_mt',
#  'meta_woz',
#  'metooma',
#  'metrec',
#  'mkb',
#  'mkqa',
#  'mlqa',
#  'mlsum',
#  'mocha',
#  'movie_rationales',
#  'mrqa',
#  'ms_marco',
#  'ms_terms',
#  'msr_genomics_kbcomp',
#  'msr_sqa',
#  'msr_text_compression',
#  'msr_zhen_translation_parity',
#  'msra_ner',
#  'mt_eng_vietnamese',
#  'muchocine',
#  'multi_booked',
#  'multi_news',
#  'multi_nli',
#  'multi_nli_mismatch',
#  'multi_para_crawl',
#  'multi_re_qa',
#  'multi_woz_v22',
#  'multi_x_science_sum',
#  'mutual_friends',
#  'mwsc',
#  'myanmar_news',
#  'narrativeqa',
#  'natural_questions',
#  'ncbi_disease',
#  'nchlt',
#  'ncslgr',
#  'nell',
#  'neural_code_search',
#  'news_commentary',
#  'newsgroup',
#  'newsph',
#  'newsph_nli',
#  'newsqa',
#  'newsroom',
#  'nkjp-ner',
#  'nli_tr',
#  'norwegian_ner',
#  'nq_open',
#  'nsmc',
#  'numer_sense',
#  'numeric_fused_head',
#  'oclar',
#  'offcombr',
#  'offenseval2020_tr',
#  'offenseval_dravidian',
#  'ofis_publik',
#  'ohsumed',
#  'omp',
#  'onestop_english',
#  'open_subtitles',
#  'openbookqa',
#  'openwebtext',
#  'opinosis',
#  'opus100',
#  'opus_books',
#  'opus_dgt',
#  'opus_dogc',
#  'opus_elhuyar',
#  'opus_euconst',
#  'opus_finlex',
#  'opus_fiskmo',
#  'opus_gnome',
#  'opus_infopankki',
#  'opus_memat',
#  'opus_montenegrinsubs',
#  'opus_openoffice',
#  'opus_paracrawl',
#  'opus_rf',
#  'opus_tedtalks',
#  'opus_ubuntu',
#  'opus_wikipedia',
#  'opus_xhosanavy',
#  'orange_sum',
#  'pandas',
#  'para_crawl',
#  'para_pat',
#  'paws',
#  'paws-x',
#  'pec',
#  'peer_read',
#  'peoples_daily_ner',
#  'per_sent',
#  'persian_ner',
#  'pg19',
#  'php',
#  'piaf',
#  'pib',
#  'piqa',
#  'poem_sentiment',
#  'polemo2',
#  'poleval2019_cyberbullying',
#  'poleval2019_mt',
#  'polsum',
#  'polyglot_ner',
#  'prachathai67k',
#  'pragmeval',
#  'proto_qa',
#  'psc',
#  'ptb_text_only',
#  'pubmed',
#  'pubmed_qa',
#  'py_ast',
#  'qa4mre',
#  'qa_srl',
#  'qa_zre',
#  'qangaroo',
#  'qanta',
#  'qasc',
#  'qed',
#  'qed_amara',
#  'quac',
#  'quail',
#  'quarel',
#  'quartz',
#  'quora',
#  'quoref',
#  'race',
#  're_dial',
#  'reasoning_bg',
#  'recipe_nlg',
#  'reclor',
#  'reddit',
#  'reddit_tifu',
#  'refresd',
#  'reuters21578',
#  'roman_urdu',
#  'ronec',
#  'ropes',
#  'rotten_tomatoes',
#  'samsum',
#  'sanskrit_classic',
#  'saudinewsnet',
#  'scan',
#  'scb_mt_enth_2020',
#  'schema_guided_dstc8',
#  'scicite',
#  'scielo',
#  'scientific_papers',
#  'scifact',
#  'sciq',
#  'scitail',
#  'scitldr',
#  'search_qa',
#  'selqa',
#  'sem_eval_2010_task_8',
#  'sem_eval_2014_task_1',
#  'sem_eval_2020_task_11',
#  'sent_comp',
#  'senti_lex',
#  'senti_ws',
#  'sentiment140',
#  'sepedi_ner',
#  'sesotho_ner_corpus',
#  'setimes',
#  'setswana_ner_corpus',
#  'sharc',
#  'sharc_modified',
#  'simple_questions_v2',
#  'siswati_ner_corpus',
#  'smartdata',
#  'sms_spam',
#  'snips_built_in_intents',
#  'snli',
#  'snow_simplified_japanese_corpus',
#  'so_stacksample',
#  'social_bias_frames',
#  'social_i_qa',
#  'sofc_materials_articles',
#  'sogou_news',
#  'spanish_billion_words',
#  'spc',
#  'species_800',
#  'spider',
#  'squad',
#  'squad_adversarial',
#  'squad_es',
#  'squad_it',
#  'squad_kor_v1',
#  'squad_kor_v2',
#  'squad_v1_pt',
#  'squad_v2',
#  'squadshifts',
#  'srwac',
#  'stereoset',
#  'stsb_mt_sv',
#  'style_change_detection',
#  'super_glue',
#  'swag',
#  'swahili',
#  'swahili_news',
#  'swedish_ner_corpus',
#  'swedish_reviews',
#  'tab_fact',
#  'tamilmixsentiment',
#  'tanzil',
#  'tapaco',
#  'tashkeela',
#  'taskmaster1',
#  'taskmaster2',
#  'taskmaster3',
#  'tatoeba',
#  'ted_hrlr',
#  'ted_iwlst2013',
#  'ted_multi',
#  'telugu_books',
#  'telugu_news',
#  'tep_en_fa_para',
#  'text',
#  'thai_toxicity_tweet',
#  'thainer',
#  'thaiqa_squad',
#  'thaisum',
#  'tilde_model',
#  'times_of_india_news_headlines',
#  'tiny_shakespeare',
#  'tlc',
#  'tmu_gfm_dataset',
#  'totto',
#  'trec',
#  'trivia_qa',
#  'tsac',
#  'ttc4900',
#  'tunizi',
#  'tuple_ie',
#  'turkish_movie_sentiment',
#  'turkish_ner',
#  'turkish_shrinked_ner',
#  'turku_ner_corpus',
#  'tweet_qa',
#  'tweets_ar_en_parallel',
#  'tweets_hate_speech_detection',
#  'twi_text_c3',
#  'twi_wordsim353',
#  'tydiqa',
#  'ubuntu_dialogs_corpus',
#  'udhr',
#  'um005',
#  'un_ga',
#  'un_multi',
#  'un_pc',
#  'universal_dependencies',
#  'urdu_fake_news',
#  'urdu_sentiment_corpus',
#  'web_nlg',
#  'web_of_science',
#  'web_questions',
#  'weibo_ner',
#  'wi_locness',
#  'wiki40b',
#  'wiki_asp',
#  'wiki_atomic_edits',
#  'wiki_auto',
#  'wiki_bio',
#  'wiki_dpr',
#  'wiki_hop',
#  'wiki_lingua',
#  'wiki_movies',
#  'wiki_qa',
#  'wiki_qa_ar',
#  'wiki_snippets',
#  'wiki_source',
#  'wiki_split',
#  'wiki_summary',
#  'wikiann',
#  'wikicorpus',
#  'wikihow',
#  'wikipedia',
#  'wikisql',
#  'wikitext',
#  'wikitext_tl39',
#  'wili_2018',
#  'wino_bias',
#  'winograd_wsc',
#  'winogrande',
#  'wiqa',
#  'wisesight1000',
#  'wisesight_sentiment',
#  'wmt14',
#  'wmt15',
#  'wmt16',
#  'wmt17',
#  'wmt18',
#  'wmt19',
#  'wmt20_mlqe_task1',
#  'wmt20_mlqe_task2',
#  'wmt20_mlqe_task3',
#  'wmt_t2t',
#  'wnut_17',
#  'wongnai_reviews',
#  'woz_dialogue',
#  'wrbsc',
#  'x_stance',
#  'xcopa',
#  'xed_en_fi',
#  'xglue',
#  'xnli',
#  'xor_tydi_qa',
#  'xquad',
#  'xquad_r',
#  'xsum',
#  'xsum_factuality',
#  'xtreme',
#  'yahoo_answers_qa',
#  'yahoo_answers_topics',
#  'yelp_polarity',
#  'yelp_review_full',
#  'yoruba_bbc_topics',
#  'yoruba_gv_ner',
#  'yoruba_text_c3',
#  'yoruba_wordsim353',
#  'youtube_caption_corrections',
#  'zest',
#  'Fraser/news-category-dataset',
#  'Fraser/python-lines',
#  'Telecom-Paris/SILICONE',
#  'cdminix/mgb1',
#  'eusip/SILICONE',
#  'german-nlp-group/german_common_crawl',
#  'joelito/ler',
#  'joelito/sem_eval_2010_task_8',
#  'k-halid/ar',
#  'lhoestq/squad',
#  'mulcyber/europarl-mono',
#  'piEsposito/br-quad-2.0',
#  'piEsposito/br_quad_20',
#  'piEsposito/squad_20_ptbr',
#  'sshleifer/pseudo_bart_xsum']

# %%
#WIKITEXT_DATASET = "wikitext-2-raw-v1"
#WIKITEXT_DATASET = "wikitext-103-raw-v1"
#WIKITEXT_DATASET = "wikitext-2-v1"
WIKITEXT_DATASET = "wikitext-103-v1"

# %%
wikitext_dataset = load_dataset('wikitext', WIKITEXT_DATASET)
train_wikitext_dataset = wikitext_dataset["train"]

# List all the available metrics
print("Available metrics: {}".format(list_metrics()))

## Load a metric
#squad_metric = load_metric('squad')
# Out:
# Reusing dataset wikitext (/home/wotan/.cache/huggingface/datasets/wikitext/wikitext-103-v1/1.0.0/47c57a6745aa5ce8e16a5355aaa4039e3aa90d1adad87cef1ad4e0f29e74ac91)
# Available metrics: ['accuracy', 'bertscore', 'bleu', 'bleurt', 'coval', 'f1', 'gleu', 'glue', 'indic_glue', 'meteor', 'precision', 'recall', 'rouge', 'sacrebleu', 'seqeval', 'squad', 'squad_v2', 'xnli']

# %%
len(train_wikitext_dataset)
# Out:
# 1801350

# %%
train_wikitext_dataset[1]
# Out:
# {'text': ' = Valkyria Chronicles III = \n'}

# %% [markdown]
# **Identify sentences and send them to Solr to be indexed. Use Spacy for sentence tokenization.**

# %%
#!python -m spacy download en_core_web_sm

# %%
nlp = spacy.load("en_core_web_sm")

# %%
class Normalizer(object):
    PUNCTUATION_CHARS = [".", ",", ":", ";", "?", "!", "¿", '"', "'"]
    
    @staticmethod
    def get_normalized_sentence(s: spacy.tokens.span.Span) -> str:
        """
        Transform a spacy Span object into a normalized string sentence:
        - Lower case.
        - Without punctuation chars.
        """
        res = [t.text.lower() for t in s if t.text not in Normalizer.PUNCTUATION_CHARS]
        return " ".join(res).strip()

# %%
def send_to_elasticsearch(s: str, model: "spacy.language.Language", es: Elasticsearch, es_index: str):
    """
    Send to Elastic Search the sentences contained in a given text.
    The text is split into sentences, normalized an then sent to ElasticSearch (one document per sentence).
    """
    doc = model(s)
    s_sentences = [Normalizer.get_normalized_sentence(sent) for sent in doc.sents]
    orig_s_sentences = [str(sent) for sent in doc.sents]
#    print(s_sentences)
    
    for i in range(len(s_sentences)):
        doc = {
            'original_text': orig_s_sentences[i],
            'text': s_sentences[i],
            'timestamp': datetime.now(),
        }
        res = es.index(index=es_index, body=doc)
    
    # TODO

# %% [markdown]
# Use the index "concept_embeddings"

# %%
ES_INDEX = "concept_embeddings"
ES_QUERY_SIZE = 1000

# %%
es = Elasticsearch(
    hosts=["localhost:9200"],
#    sniff_on_start=True,
#    sniff_on_connection_fail=True,
#    sniffer_timeout=60
)

# %%
#?es.index

# %% [markdown]
# See https://elasticsearch-py.readthedocs.io/en/7.10.0/api.html

# %%
#send_to_elasticsearch(train_wikitext_dataset[4]["text"], nlp, es, ES_INDEX)

# %%
es.count()
# Out:
# {'count': 3321,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %%
es.search(size=1000, index=ES_INDEX)
# Out:
# {'took': 117,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'aFqKs3YB9GIGtQkyQvsE',
#     '_score': 1.0,
#     '_source': {'original_text': 'She hosted television shows in Bahrain at the age of fourteen .',
#      'text': 'she hosted television shows in bahrain at the age of fourteen',
#      'timestamp': '2020-12-30T13:05:51.236269'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'aVqKs3YB9GIGtQkyQvsR',
#     '_score': 1.0,
#     '_source': {'original_text': 'After receiving her early education in Bahrain , she pursued a degree in mass communication from the University of Sydney in Australia .',
#      'text': 'after receiving her early education in bahrain she pursued a degree in mass communication from the university of sydney in australia',
#      'timestamp': '2020-12-30T13:05:51.248996'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'alqKs3YB9GIGtQkyQvsc',
#     '_score': 1.0,
#     '_source': {'original_text': 'After graduating she worked as a television reporter in Sri Lanka .',
#      'text': 'after graduating she worked as a television reporter in sri lanka',
#      'timestamp': '2020-12-30T13:05:51.259826'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'a1qKs3YB9GIGtQkyQvsn',
#     '_score': 1.0,
#     '_source': {'original_text': 'She also attended the Berlitz school of languages , where she learnt Spanish and improved her French and Arabic . \n',
#      'text': 'she also attended the berlitz school of languages where she learnt spanish and improved her french and arabic',
#      'timestamp': '2020-12-30T13:05:51.270977'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'bFqKs3YB9GIGtQkyQvtQ',
#     '_score': 1.0,
#     '_source': {'original_text': ' According to Fernandez , she had aspired to become an actress at a young age and fantasized about becoming a Hollywood movie star .',
#      'text': 'according to fernandez she had aspired to become an actress at a young age and fantasized about becoming a hollywood movie star',
#      'timestamp': '2020-12-30T13:05:51.311509'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'bVqKs3YB9GIGtQkyQvtb',
#     '_score': 1.0,
#     '_source': {'original_text': 'She received some training at the John School of Acting .',
#      'text': 'she received some training at the john school of acting',
#      'timestamp': '2020-12-30T13:05:51.322880'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'blqKs3YB9GIGtQkyQvtm',
#     '_score': 1.0,
#     '_source': {'original_text': 'Although , she was a television reporter , she accepted offers in the modeling industry , which came as a result of her pageant success .',
#      'text': 'although she was a television reporter she accepted offers in the modeling industry which came as a result of her pageant success',
#      'timestamp': '2020-12-30T13:05:51.333894'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'b1qKs3YB9GIGtQkyQvtx',
#     '_score': 1.0,
#     '_source': {'original_text': 'In 2006 , she was crowned the winner of the Miss Universe Sri Lanka pageant and represented Sri Lanka at the world Miss Universe 2006 pageant held in Los Angeles .',
#      'text': 'in 2006 she was crowned the winner of the miss universe sri lanka pageant and represented sri lanka at the world miss universe 2006 pageant held in los angeles',
#      'timestamp': '2020-12-30T13:05:51.344811'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'cFqKs3YB9GIGtQkyQvt8',
#     '_score': 1.0,
#     '_source': {'original_text': 'In a 2015 interview , Fernandez described the modeling industry as " a good training ground " and said : " It is a medium that is about shedding your inhibitions , knowing your body , confidence " .',
#      'text': 'in a 2015 interview fernandez described the modeling industry as a good training ground and said it is a medium that is about shedding your inhibitions knowing your body confidence',
#      'timestamp': '2020-12-30T13:05:51.355962'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'cVqKs3YB9GIGtQkyQvuH',
#     '_score': 1.0,
#     '_source': {'original_text': 'In 2006 , she appeared in a music video for the song " O Sathi " by music duo <unk> and <unk',
#      'text': 'in 2006 she appeared in a music video for the song o sathi by music duo < unk > and < unk',
#      'timestamp': '2020-12-30T13:05:51.367148'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'clqKs3YB9GIGtQkyQvuS',
#     '_score': 1.0,
#     '_source': {'original_text': '> . \n',
#      'text': '>',
#      'timestamp': '2020-12-30T13:05:51.377590'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'c1qKs3YB9GIGtQkyQvuj',
#     '_score': 1.0,
#     '_source': {'original_text': ' = =',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:05:51.394418'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'dFqKs3YB9GIGtQkyQvuu',
#     '_score': 1.0,
#     '_source': {'original_text': 'Acting career = = \n',
#      'text': 'acting career = =',
#      'timestamp': '2020-12-30T13:05:51.406170'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'dVqKs3YB9GIGtQkyQvvC',
#     '_score': 1.0,
#     '_source': {'original_text': ' = =',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:05:51.426267'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'dlqKs3YB9GIGtQkyQvvO',
#     '_score': 1.0,
#     '_source': {'original_text': '= 2009 –',
#      'text': '= 2009 –',
#      'timestamp': '2020-12-30T13:05:51.437989'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'd1qKs3YB9GIGtQkyQvvZ',
#     '_score': 1.0,
#     '_source': {'original_text': '2013 = = = \n',
#      'text': '2013 = = =',
#      'timestamp': '2020-12-30T13:05:51.449360'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'eFqKs3YB9GIGtQkyQvv1',
#     '_score': 1.0,
#     '_source': {'original_text': ' In 2009 , Fernandez traveled to India for a modeling assignment .',
#      'text': 'in 2009 fernandez traveled to india for a modeling assignment',
#      'timestamp': '2020-12-30T13:05:51.476750'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'eVqKs3YB9GIGtQkyQ_sB',
#     '_score': 1.0,
#     '_source': {'original_text': "She studied acting under the mentorship of theatre director Barry John , and successfully auditioned for Sujoy Ghosh 's fantasy film Aladin ( 2009 ) her acting debut .",
#      'text': "she studied acting under the mentorship of theatre director barry john and successfully auditioned for sujoy ghosh 's fantasy film aladin ( 2009 ) her acting debut",
#      'timestamp': '2020-12-30T13:05:51.488521'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'elqKs3YB9GIGtQkyQ_sM',
#     '_score': 1.0,
#     '_source': {'original_text': 'She played the love interest of <unk>',
#      'text': 'she played the love interest of < unk >',
#      'timestamp': '2020-12-30T13:05:51.500205'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'e1qKs3YB9GIGtQkyQ_sY',
#     '_score': 1.0,
#     '_source': {'original_text': "Deshmukh 's character , a role based on the Princess Jasmine character .",
#      'text': "deshmukh 's character a role based on the princess jasmine character",
#      'timestamp': '2020-12-30T13:05:51.511736'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'fFqKs3YB9GIGtQkyQ_sj',
#     '_score': 1.0,
#     '_source': {'original_text': 'Fernandez garnered mixed reviews for her performance .',
#      'text': 'fernandez garnered mixed reviews for her performance',
#      'timestamp': '2020-12-30T13:05:51.523151'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'fVqKs3YB9GIGtQkyQ_sv',
#     '_score': 1.0,
#     '_source': {'original_text': 'Anupama Chopra of NDTV called her a " plastic debutant [ e ] " , and Rajeev Masand of CNN',
#      'text': 'anupama chopra of ndtv called her a plastic debutant [ e ] and rajeev masand of cnn',
#      'timestamp': '2020-12-30T13:05:51.534989'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'flqKs3YB9GIGtQkyQ_s8',
#     '_score': 1.0,
#     '_source': {'original_text': '@-@ IBN felt that she was : " easy on the eyes and appears confident but has precious little to do " .',
#      'text': '@-@ ibn felt that she was easy on the eyes and appears confident but has precious little to do',
#      'timestamp': '2020-12-30T13:05:51.547373'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'f1qKs3YB9GIGtQkyQ_tI',
#     '_score': 1.0,
#     '_source': {'original_text': 'Although the film was a critical and commercial failure , she won the IIFA Award for Star Debut of the Year - Female . \n',
#      'text': 'although the film was a critical and commercial failure she won the iifa award for star debut of the year - female',
#      'timestamp': '2020-12-30T13:05:51.559387'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'gFqKs3YB9GIGtQkyQ_tp',
#     '_score': 1.0,
#     '_source': {'original_text': ' In 2010 , Fernandez appeared opposite Deshmukh in the science fiction romantic comedy Jaane Kahan Se Aayi Hai .',
#      'text': 'in 2010 fernandez appeared opposite deshmukh in the science fiction romantic comedy jaane kahan se aayi hai',
#      'timestamp': '2020-12-30T13:05:51.592983'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'gVqKs3YB9GIGtQkyQ_t1',
#     '_score': 1.0,
#     '_source': {'original_text': 'She was cast as a girl from Venus , who lands on Earth in search of love .',
#      'text': 'she was cast as a girl from venus who lands on earth in search of love',
#      'timestamp': '2020-12-30T13:05:51.604822'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'glqKs3YB9GIGtQkyQ_uB',
#     '_score': 1.0,
#     '_source': {'original_text': 'The film , along with Fernandez \'s performance , received poor reviews ; Rediff.com \'s Sukanya Verma noted : " She gamely makes a fool of herself whilst aping the actions of movie stars , ranging from Sridevi \'s <unk> dance , Mithun Chakravarthy \'s Disco Dancer moves , to Big B \'s violent <unk> in Hum .',
#      'text': "the film along with fernandez 's performance received poor reviews rediff.com 's sukanya verma noted she gamely makes a fool of herself whilst aping the actions of movie stars ranging from sridevi 's < unk > dance mithun chakravarthy 's disco dancer moves to big b 's violent < unk > in hum",
#      'timestamp': '2020-12-30T13:05:51.616428'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'g1qKs3YB9GIGtQkyQ_uL',
#     '_score': 1.0,
#     '_source': {'original_text': 'Her Tara could be a keeper if only Jaane Kahan Se Aayi Hai wasn \'t so intent on turning her into a love @-@ struck Barbie . "',
#      'text': 'her tara could be a keeper if only jaane kahan se aayi hai wasn t so intent on turning her into a love @-@ struck barbie',
#      'timestamp': '2020-12-30T13:05:51.626829'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'hFqKs3YB9GIGtQkyQ_uV',
#     '_score': 1.0,
#     '_source': {'original_text': 'Critic Anupama Chopra also criticized Fernandez , calling her " a pin @-@ prick on a balloon " .',
#      'text': 'critic anupama chopra also criticized fernandez calling her a pin @-@ prick on a balloon',
#      'timestamp': '2020-12-30T13:05:51.637306'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'hVqKs3YB9GIGtQkyQ_ug',
#     '_score': 1.0,
#     '_source': {'original_text': 'Later that year , she made a cameo appearance in Sajid Khan \'s Housefull in the song " <unk> " . \n',
#      'text': "later that year she made a cameo appearance in sajid khan 's housefull in the song < unk >",
#      'timestamp': '2020-12-30T13:05:51.647641'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'hlqKs3YB9GIGtQkyQ_vB',
#     '_score': 1.0,
#     '_source': {'original_text': " Mahesh Bhatt 's thriller Murder 2 was Fernandez 's first commercial success and marker a turning point in her career .",
#      'text': "mahesh bhatt 's thriller murder 2 was fernandez 's first commercial success and marker a turning point in her career",
#      'timestamp': '2020-12-30T13:05:51.681022'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'h1qKs3YB9GIGtQkyQ_vM',
#     '_score': 1.0,
#     '_source': {'original_text': 'She took on the role of Priya , a lonely model who is in a confused relationship with Arjun Bhagwat ( played by Emraan Hashmi ) .',
#      'text': 'she took on the role of priya a lonely model who is in a confused relationship with arjun bhagwat ( played by emraan hashmi )',
#      'timestamp': '2020-12-30T13:05:51.691595'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'iFqKs3YB9GIGtQkyQ_vW',
#     '_score': 1.0,
#     '_source': {'original_text': 'Fernandez was praised for the her performance , and for the boldness and sex appeal she displayed in the film .',
#      'text': 'fernandez was praised for the her performance and for the boldness and sex appeal she displayed in the film',
#      'timestamp': '2020-12-30T13:05:51.702066'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'iVqKs3YB9GIGtQkyQ_vh',
#     '_score': 1.0,
#     '_source': {'original_text': 'Gaurav Malini of The Times of India stated that she was " tastefully tempting " but noted that her romance with Hashmi was " literally half @-@ baked " .',
#      'text': 'gaurav malini of the times of india stated that she was tastefully tempting but noted that her romance with hashmi was literally half @-@ baked',
#      'timestamp': '2020-12-30T13:05:51.712483'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ilqKs3YB9GIGtQkyQ_vv',
#     '_score': 1.0,
#     '_source': {'original_text': 'The following year , Fernandez appeared in the ensemble comedy Housefull 2 alongside Akshay Kumar , John Abraham , and Asin .',
#      'text': 'the following year fernandez appeared in the ensemble comedy housefull 2 alongside akshay kumar john abraham and asin',
#      'timestamp': '2020-12-30T13:05:51.726782'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'i1qKs3YB9GIGtQkyQ_v5',
#     '_score': 1.0,
#     '_source': {'original_text': 'It became one of the top grossing productions of India that year and earned ₹ 1 @.@ 86 billion ( US $ 28 million ) worldwide .',
#      'text': 'it became one of the top grossing productions of india that year and earned ₹ 1 @.@ 86 billion ( us $ 28 million ) worldwide',
#      'timestamp': '2020-12-30T13:05:51.737067'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'jFqKs3YB9GIGtQkyRPsD',
#     '_score': 1.0,
#     '_source': {'original_text': 'Fernandez received mostly negative reviews for her performance .',
#      'text': 'fernandez received mostly negative reviews for her performance',
#      'timestamp': '2020-12-30T13:05:51.747401'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'jVqKs3YB9GIGtQkyRPsP',
#     '_score': 1.0,
#     '_source': {'original_text': 'While Gaurav Malini praised her for her looks , NDTV called her a " <unk> bimbo " who " find [ s ]',
#      'text': 'while gaurav malini praised her for her looks ndtv called her a < unk > bimbo who find [ s ]',
#      'timestamp': '2020-12-30T13:05:51.759145'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'jlqKs3YB9GIGtQkyRPsb',
#     '_score': 1.0,
#     '_source': {'original_text': 'no pleasure in [ her role ] " .',
#      'text': 'no pleasure in [ her role ]',
#      'timestamp': '2020-12-30T13:05:51.770615'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'j1qKs3YB9GIGtQkyRPsm',
#     '_score': 1.0,
#     '_source': {'original_text': 'Despite the negative reviews , Fernandez received a Best Supporting Actress nomination at the 14th IIFA Awards for her performance . \n',
#      'text': 'despite the negative reviews fernandez received a best supporting actress nomination at the 14th iifa awards for her performance',
#      'timestamp': '2020-12-30T13:05:51.782142'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'kFqKs3YB9GIGtQkyRPtG',
#     '_score': 1.0,
#     '_source': {'original_text': ' Fernandez \'s first release of 2013 was Race 2 , an ensemble action thriller ( alongside Saif Ali Khan , John Abraham , Deepika Padukone , Ameesha Patel , and Anil Kapoor ) ) , described as the " cinematic equivalent of a trashy novel " by critic Rajeev Masand .',
#      'text': "fernandez 's first release of 2013 was race 2 an ensemble action thriller ( alongside saif ali khan john abraham deepika padukone ameesha patel and anil kapoor ) ) described as the cinematic equivalent of a trashy novel by critic rajeev masand",
#      'timestamp': '2020-12-30T13:05:51.813964'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'kVqKs3YB9GIGtQkyRPtS',
#     '_score': 1.0,
#     '_source': {'original_text': 'She played <unk> ,',
#      'text': 'she played < unk >',
#      'timestamp': '2020-12-30T13:05:51.825848'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'klqKs3YB9GIGtQkyRPtd',
#     '_score': 1.0,
#     '_source': {'original_text': 'a femme fatale , a role which required her learn fencing and some acrobatics .',
#      'text': 'a femme fatale a role which required her learn fencing and some acrobatics',
#      'timestamp': '2020-12-30T13:05:51.837389'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'k1qKs3YB9GIGtQkyRPtp',
#     '_score': 1.0,
#     '_source': {'original_text': 'The film emerged as a commercial success , with the domestic gross of more than ₹ 1 billion ( US $ 15 million ) .',
#      'text': 'the film emerged as a commercial success with the domestic gross of more than ₹ 1 billion ( us $ 15 million )',
#      'timestamp': '2020-12-30T13:05:51.848986'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'lFqKs3YB9GIGtQkyRPt1',
#     '_score': 1.0,
#     '_source': {'original_text': 'In a particularly scathing review , Saibal Chatterjee of NDTV wrote that both Fernandez and Padukone " strut around like wound @-@ up automatons that are all decked @-@ up but have nowhere to go . "',
#      'text': 'in a particularly scathing review saibal chatterjee of ndtv wrote that both fernandez and padukone strut around like wound @-@ up automatons that are all decked @-@ up but have nowhere to go',
#      'timestamp': '2020-12-30T13:05:51.860715'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'lVqKs3YB9GIGtQkyRPuA',
#     '_score': 1.0,
#     '_source': {'original_text': 'Fernandez also appeared in an item number ( music video ) titled " Jaadu Ki <unk> " for Prabhu Deva \'s <unk> <unk',
#      'text': "fernandez also appeared in an item number ( music video ) titled jaadu ki < unk > for prabhu deva 's < unk > < unk",
#      'timestamp': '2020-12-30T13:05:51.872375'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'llqKs3YB9GIGtQkyRPuM',
#     '_score': 1.0,
#     '_source': {'original_text': '> <unk',
#      'text': '> < unk',
#      'timestamp': '2020-12-30T13:05:51.883942'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'l1qKs3YB9GIGtQkyRPuY',
#     '_score': 1.0,
#     '_source': {'original_text': '> . \n',
#      'text': '>',
#      'timestamp': '2020-12-30T13:05:51.895606'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mFqKs3YB9GIGtQkyRPuq',
#     '_score': 1.0,
#     '_source': {'original_text': ' = =',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:05:51.914102'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mVqKs3YB9GIGtQkyRPu2',
#     '_score': 1.0,
#     '_source': {'original_text': '= 2014 – present = = = \n',
#      'text': '= 2014 – present = = =',
#      'timestamp': '2020-12-30T13:05:51.925994'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mlqKs3YB9GIGtQkyRPvR',
#     '_score': 1.0,
#     '_source': {'original_text': " In 2014 , Fernandez appeared in Sajid Nadiadwala 's directorial debut — the action film Kick , a remake of a 2009 Telugu film of same name .",
#      'text': "in 2014 fernandez appeared in sajid nadiadwala 's directorial debut — the action film kick a remake of a 2009 telugu film of same name",
#      'timestamp': '2020-12-30T13:05:51.952190'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'm1qKs3YB9GIGtQkyRPvb',
#     '_score': 1.0,
#     '_source': {'original_text': 'She starred opposite Salman Khan , playing Shaina , a psychiatry student .',
#      'text': 'she starred opposite salman khan playing shaina a psychiatry student',
#      'timestamp': '2020-12-30T13:05:51.962758'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'nFqKs3YB9GIGtQkyRPvl',
#     '_score': 1.0,
#     '_source': {'original_text': 'She retained her real voice for the first time in Kick .',
#      'text': 'she retained her real voice for the first time in kick',
#      'timestamp': '2020-12-30T13:05:51.973316'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'nVqKs3YB9GIGtQkyRPvw',
#     '_score': 1.0,
#     '_source': {'original_text': 'While Sneha May Francis commented that she is : " incredibly dazzling , and moves like a magic " , Raja Sen of Rediff.com was more critical of her dialogue delivery , calling it " unfortunate .',
#      'text': 'while sneha may francis commented that she is incredibly dazzling and moves like a magic raja sen of rediff.com was more critical of her dialogue delivery calling it unfortunate',
#      'timestamp': '2020-12-30T13:05:51.983789'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'nlqKs3YB9GIGtQkyRPv7',
#     '_score': 1.0,
#     '_source': {'original_text': '"',
#      'text': '',
#      'timestamp': '2020-12-30T13:05:51.995106'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'n1qKs3YB9GIGtQkyRfsG',
#     '_score': 1.0,
#     '_source': {'original_text': 'The film received mixed reviews from critics , but with worldwide revenue of over ₹ 3 @.@ 75 billion ( US $ 56 million ) , it became the fourth highest @-@ grossing Bollywood film .',
#      'text': 'the film received mixed reviews from critics but with worldwide revenue of over ₹ 3 @.@ 75 billion ( us $ 56 million ) it became the fourth highest @-@ grossing bollywood film',
#      'timestamp': '2020-12-30T13:05:52.005887'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'oFqKs3YB9GIGtQkyRfsQ',
#     '_score': 1.0,
#     '_source': {'original_text': 'The film established Fernandez as one of the most popular Bollywood actresses . \n',
#      'text': 'the film established fernandez as one of the most popular bollywood actresses',
#      'timestamp': '2020-12-30T13:05:52.016406'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'oVqKs3YB9GIGtQkyRfst',
#     '_score': 1.0,
#     '_source': {'original_text': ' In 2015 , Fernandez featured in Vicky Singh \'s Roy , a romantic thriller , which critic Sarita A. Tanwar described as a " boring , exhausting and pretentious " film .',
#      'text': "in 2015 fernandez featured in vicky singh 's roy a romantic thriller which critic sarita a. tanwar described as a boring exhausting and pretentious film",
#      'timestamp': '2020-12-30T13:05:52.045112'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'olqKs3YB9GIGtQkyRfs4',
#     '_score': 1.0,
#     '_source': {'original_text': 'Fernandez played dual roles , Ayesha Aamir , a filmmaker in a relationship with another filmmaker ( played by Arjun Rampal ) and Tia Desai , a girl in love with a thief ( played by Ranbir Kapoor ) .',
#      'text': 'fernandez played dual roles ayesha aamir a filmmaker in a relationship with another filmmaker ( played by arjun rampal ) and tia desai a girl in love with a thief ( played by ranbir kapoor )',
#      'timestamp': '2020-12-30T13:05:52.055861'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'o1qKs3YB9GIGtQkyRftC',
#     '_score': 1.0,
#     '_source': {'original_text': 'While India TV called it " her best act till date " , critic Rajeev Masand felt that she " appears miscast in a part that required greater range .',
#      'text': 'while india tv called it her best act till date critic rajeev masand felt that she appears miscast in a part that required greater range',
#      'timestamp': '2020-12-30T13:05:52.066313'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'pFqKs3YB9GIGtQkyRftN',
#     '_score': 1.0,
#     '_source': {'original_text': '"',
#      'text': '',
#      'timestamp': '2020-12-30T13:05:52.076934'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'pVqKs3YB9GIGtQkyRftZ',
#     '_score': 1.0,
#     '_source': {'original_text': 'Roy failed to meet its box @-@ office expectations , and was a commercial failure .',
#      'text': 'roy failed to meet its box @-@ office expectations and was a commercial failure',
#      'timestamp': '2020-12-30T13:05:52.088655'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'plqKs3YB9GIGtQkyRftk',
#     '_score': 1.0,
#     '_source': {'original_text': 'Later that year , she appeared in a guest appearance for the comedy @-@ satire <unk',
#      'text': 'later that year she appeared in a guest appearance for the comedy @-@ satire < unk',
#      'timestamp': '2020-12-30T13:05:52.100215'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'p1qKs3YB9GIGtQkyRftw',
#     '_score': 1.0,
#     '_source': {'original_text': '> . \n',
#      'text': '>',
#      'timestamp': '2020-12-30T13:05:52.111807'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'qFqKs3YB9GIGtQkyRfuQ',
#     '_score': 1.0,
#     '_source': {'original_text': " Karan Malhotra 's action drama Brothers was Fernandez 's next release .",
#      'text': "karan malhotra 's action drama brothers was fernandez 's next release",
#      'timestamp': '2020-12-30T13:05:52.143314'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'qVqKs3YB9GIGtQkyRfub',
#     '_score': 1.0,
#     '_source': {'original_text': 'Co @-@ starring alongside Akshay Kumar and Sidharth Malhotra , Fernandez played Jenny , a fearless mother struggling for her child , a role which she described as " challenging " , " intense " , and " difficult " .',
#      'text': 'co @-@ starring alongside akshay kumar and sidharth malhotra fernandez played jenny a fearless mother struggling for her child a role which she described as challenging intense and difficult',
#      'timestamp': '2020-12-30T13:05:52.155033'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'qlqKs3YB9GIGtQkyRfun',
#     '_score': 1.0,
#     '_source': {'original_text': 'The role marked a departure from the glamorous characters that she had a reputation for portraying .',
#      'text': 'the role marked a departure from the glamorous characters that she had a reputation for portraying',
#      'timestamp': '2020-12-30T13:05:52.166553'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'q1qKs3YB9GIGtQkyRfuy',
#     '_score': 1.0,
#     '_source': {'original_text': 'Film critics praised her performance , though their response to the film was mixed .',
#      'text': 'film critics praised her performance though their response to the film was mixed',
#      'timestamp': '2020-12-30T13:05:52.178095'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'rFqKs3YB9GIGtQkyRfu-',
#     '_score': 1.0,
#     '_source': {'original_text': '<unk>',
#      'text': '< unk >',
#      'timestamp': '2020-12-30T13:05:52.189647'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'rVqKs3YB9GIGtQkyRfvJ',
#     '_score': 1.0,
#     '_source': {'original_text': 'Sharma of Zee News called her character " soft , timid and promising " , and praised her for : " convincingly pull [ ing ] off a pleasing character of a street fighter \'s wife " .',
#      'text': "sharma of zee news called her character soft timid and promising and praised her for convincingly pull [ ing ] off a pleasing character of a street fighter 's wife",
#      'timestamp': '2020-12-30T13:05:52.201282'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'rlqKs3YB9GIGtQkyRfvV',
#     '_score': 1.0,
#     '_source': {'original_text': 'Film critic Subhash K. Jha noted that she : " ... in a limited role gives her finest emotive shot " , while critic Raja Sen remarked : " [ she ] plays Kumar \'s long @-@ sobbing wife who gets so deliriously happy on seeing a text message that it may well have contained news about a Kick sequel . " \n',
#      'text': "film critic subhash k. jha noted that she ... in a limited role gives her finest emotive shot while critic raja sen remarked [ she ] plays kumar 's long @-@ sobbing wife who gets so deliriously happy on seeing a text message that it may well have contained news about a kick sequel",
#      'timestamp': '2020-12-30T13:05:52.212862'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'r1qKs3YB9GIGtQkyRfvw',
#     '_score': 1.0,
#     '_source': {'original_text': ' As of September 2015 , Fernandez has several projects in various stages of production .',
#      'text': 'as of september 2015 fernandez has several projects in various stages of production',
#      'timestamp': '2020-12-30T13:05:52.239509'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'sFqKs3YB9GIGtQkyRfv7',
#     '_score': 1.0,
#     '_source': {'original_text': 'She has completed shooting for Chandran <unk',
#      'text': 'she has completed shooting for chandran < unk',
#      'timestamp': '2020-12-30T13:05:52.251328'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'sVqKs3YB9GIGtQkyRvsG',
#     '_score': 1.0,
#     '_source': {'original_text': "> 's English @-@",
#      'text': "> 's english @-@",
#      'timestamp': '2020-12-30T13:05:52.261594'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'slqKs3YB9GIGtQkyRvsQ',
#     '_score': 1.0,
#     '_source': {'original_text': 'Sri Lankan crime @-@ thriller',
#      'text': 'sri lankan crime @-@ thriller',
#      'timestamp': '2020-12-30T13:05:52.272148'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 's1qKs3YB9GIGtQkyRvsb',
#     '_score': 1.0,
#     '_source': {'original_text': 'According to Mathew , and the horror thriller Definition of Fear , which marks her Hollywood debut .',
#      'text': 'according to mathew and the horror thriller definition of fear which marks her hollywood debut',
#      'timestamp': '2020-12-30T13:05:52.282614'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tFqKs3YB9GIGtQkyRvsl',
#     '_score': 1.0,
#     '_source': {'original_text': "Fernandez has also signed on to appear in three other projects — Rohit Dhawan 's <unk> opposite Varun Dhawan and John Abraham as a part of three @-@ film deal with Nadiadwala Grandson Entertainment , Remo D 'Souza 's Flying Jat opposite Tiger Shroff , and in an Indo @-@ Chinese film starring opposite Abhay Deol , Amitabh Bachchan , and Jackie Chan titled Gold Struck . \n",
#      'text': "fernandez has also signed on to appear in three other projects — rohit dhawan 's < unk > opposite varun dhawan and john abraham as a part of three @-@ film deal with nadiadwala grandson entertainment remo d souza 's flying jat opposite tiger shroff and in an indo @-@ chinese film starring opposite abhay deol amitabh bachchan and jackie chan titled gold struck",
#      'timestamp': '2020-12-30T13:05:52.293153'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tVqKs3YB9GIGtQkyRvs5',
#     '_score': 1.0,
#     '_source': {'original_text': ' =',
#      'text': '=',
#      'timestamp': '2020-12-30T13:05:52.312304'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tlqKs3YB9GIGtQkyRvtD',
#     '_score': 1.0,
#     '_source': {'original_text': '=',
#      'text': '=',
#      'timestamp': '2020-12-30T13:05:52.322861'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 't1qKs3YB9GIGtQkyRvtN',
#     '_score': 1.0,
#     '_source': {'original_text': 'Personal life and other work = = \n',
#      'text': 'personal life and other work = =',
#      'timestamp': '2020-12-30T13:05:52.333323'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'uFqKs3YB9GIGtQkyRvtm',
#     '_score': 1.0,
#     '_source': {'original_text': ' Fernandez shares a close bond with her family , and admits to missing being around them .',
#      'text': 'fernandez shares a close bond with her family and admits to missing being around them',
#      'timestamp': '2020-12-30T13:05:52.358215'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'uVqKs3YB9GIGtQkyRvtx',
#     '_score': 1.0,
#     '_source': {'original_text': 'She says : " I miss them so much everyday .',
#      'text': 'she says i miss them so much everyday',
#      'timestamp': '2020-12-30T13:05:52.368676'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ulqKs3YB9GIGtQkyRvt7',
#     '_score': 1.0,
#     '_source': {'original_text': "You don 't realise when you live away from home how difficult life can be [ ... ]",
#      'text': 'you don t realise when you live away from home how difficult life can be [ ... ]',
#      'timestamp': '2020-12-30T13:05:52.379159'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'u1qKs3YB9GIGtQkyRvuG',
#     '_score': 1.0,
#     '_source': {'original_text': 'At the same time , staying away from them has taught me to be more responsible .',
#      'text': 'at the same time staying away from them has taught me to be more responsible',
#      'timestamp': '2020-12-30T13:05:52.389619'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'vFqKs3YB9GIGtQkyRvuQ',
#     '_score': 1.0,
#     '_source': {'original_text': 'It has taught me so many things about myself , about priorities and time management .',
#      'text': 'it has taught me so many things about myself about priorities and time management',
#      'timestamp': '2020-12-30T13:05:52.400207'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'vVqKs3YB9GIGtQkyRvub',
#     '_score': 1.0,
#     '_source': {'original_text': '"',
#      'text': '',
#      'timestamp': '2020-12-30T13:05:52.410866'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'vlqKs3YB9GIGtQkyRvum',
#     '_score': 1.0,
#     '_source': {'original_text': 'In March 2012 , Fernandez turned vegetarian for a 40 @-@ day period to observe Lent , a period from Ash Wednesday to Holy Saturday . \n',
#      'text': 'in march 2012 fernandez turned vegetarian for a 40 @-@ day period to observe lent a period from ash wednesday to holy saturday',
#      'timestamp': '2020-12-30T13:05:52.421686'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'v1qKs3YB9GIGtQkyRvvB',
#     '_score': 1.0,
#     '_source': {'original_text': " In 2008 , Fernandez started dating Bahraini prince Hassan bin Rashid Al Khalifa , whom she met at a mutual friend 's party ; they separated in 2011 .",
#      'text': "in 2008 fernandez started dating bahraini prince hassan bin rashid al khalifa whom she met at a mutual friend 's party they separated in 2011",
#      'timestamp': '2020-12-30T13:05:52.448254'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'wFqKs3YB9GIGtQkyRvvN',
#     '_score': 1.0,
#     '_source': {'original_text': 'While filming Housefull 2 in 2011 , Fernandez began a romantic relationship with director Sajid Khan .',
#      'text': 'while filming housefull 2 in 2011 fernandez began a romantic relationship with director sajid khan',
#      'timestamp': '2020-12-30T13:05:52.460871'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'wVqKs3YB9GIGtQkyRvvZ',
#     '_score': 1.0,
#     '_source': {'original_text': 'The relationship attracted media coverage in India and there was speculation of an impending wedding .',
#      'text': 'the relationship attracted media coverage in india and there was speculation of an impending wedding',
#      'timestamp': '2020-12-30T13:05:52.472979'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'wlqKs3YB9GIGtQkyRvvl',
#     '_score': 1.0,
#     '_source': {'original_text': 'However , the relationship ended in May 2013 . \n',
#      'text': 'however the relationship ended in may 2013',
#      'timestamp': '2020-12-30T13:05:52.484791'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'w1qKs3YB9GIGtQkyR_sK',
#     '_score': 1.0,
#     '_source': {'original_text': ' In addition to acting in films , Fernandez has supported charitable organisations and a number of causes .',
#      'text': 'in addition to acting in films fernandez has supported charitable organisations and a number of causes',
#      'timestamp': '2020-12-30T13:05:52.521926'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xFqKs3YB9GIGtQkyR_sW',
#     '_score': 1.0,
#     '_source': {'original_text': 'In 2011 , on the behalf of People for the Ethical Treatment of Animals ( PETA ) , she sent a letter to the Mumbai Municipal Commissioner asking for an end to horse @-@ drawn carriage rides in Mumbai .',
#      'text': 'in 2011 on the behalf of people for the ethical treatment of animals ( peta ) she sent a letter to the mumbai municipal commissioner asking for an end to horse @-@ drawn carriage rides in mumbai',
#      'timestamp': '2020-12-30T13:05:52.534021'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xVqKs3YB9GIGtQkyR_si',
#     '_score': 1.0,
#     '_source': {'original_text': 'In early 2013 , she asked the consulate general of the Philippines , William John T Perera in Colombo , to hasten the transfer of an elephant from its inadequate housing at the Manila Zoo to a humane sanctuary .',
#      'text': 'in early 2013 she asked the consulate general of the philippines william john t perera in colombo to hasten the transfer of an elephant from its inadequate housing at the manila zoo to a humane sanctuary',
#      'timestamp': '2020-12-30T13:05:52.545895'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xlqKs3YB9GIGtQkyR_su',
#     '_score': 1.0,
#     '_source': {'original_text': "Later that year , she auctioned a breakfast in Mayfair , London , where she raised around £ 4000 for the Pratham NGO , which helps children 's primary education .",
#      'text': "later that year she auctioned a breakfast in mayfair london where she raised around £ 4000 for the pratham ngo which helps children 's primary education",
#      'timestamp': '2020-12-30T13:05:52.557791'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'x1qKs3YB9GIGtQkyR_s6',
#     '_score': 1.0,
#     '_source': {'original_text': 'In 2014 , Fernandez was named " Woman Of The Year " by PETA ( India ) for advocating the protection of animals .',
#      'text': 'in 2014 fernandez was named woman of the year by peta ( india ) for advocating the protection of animals',
#      'timestamp': '2020-12-30T13:05:52.569679'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'yFqKs3YB9GIGtQkyR_tG',
#     '_score': 1.0,
#     '_source': {'original_text': 'The following year , she auctioned her outfits on an online portal for a philanthropic cause .',
#      'text': 'the following year she auctioned her outfits on an online portal for a philanthropic cause',
#      'timestamp': '2020-12-30T13:05:52.581592'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'yVqKs3YB9GIGtQkyR_tR',
#     '_score': 1.0,
#     '_source': {'original_text': 'Some of her outfits included the ones she wore in the song " Party On My Mind " ( from Race 2 ) and " Hangover " ( from Kick ) .',
#      'text': 'some of her outfits included the ones she wore in the song party on my mind ( from race 2 ) and hangover ( from kick )',
#      'timestamp': '2020-12-30T13:05:52.593305'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ylqKs3YB9GIGtQkyR_tc',
#     '_score': 1.0,
#     '_source': {'original_text': 'In March 2016 , she was part of " Jacqueline Builds " campaign that raised funds for the victims of the 2015 South Indian floods . \n',
#      'text': 'in march 2016 she was part of jacqueline builds campaign that raised funds for the victims of the 2015 south indian floods',
#      'timestamp': '2020-12-30T13:05:52.603622'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'y1qKs3YB9GIGtQkyR_t1',
#     '_score': 1.0,
#     '_source': {'original_text': ' Fernandez has participated in several concert tours and televised award ceremonies .',
#      'text': 'fernandez has participated in several concert tours and televised award ceremonies',
#      'timestamp': '2020-12-30T13:05:52.628345'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'zFqKs3YB9GIGtQkyR_t_',
#     '_score': 1.0,
#     '_source': {'original_text': 'In 2013 , she performed at the Temptations Reloaded in Auckland , Perth , and Sydney alongside Shah Rukh Khan , Rani Mukerji , and Madhuri Dixit .',
#      'text': 'in 2013 she performed at the temptations reloaded in auckland perth and sydney alongside shah rukh khan rani mukerji and madhuri dixit',
#      'timestamp': '2020-12-30T13:05:52.638816'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'zVqKs3YB9GIGtQkyR_uJ',
#     '_score': 1.0,
#     '_source': {'original_text': 'She also performed at the live talent show " Got Talent World Stage Live " with Khan , Priyanka Chopra and Varun Dhawan the following year .',
#      'text': 'she also performed at the live talent show got talent world stage live with khan priyanka chopra and varun dhawan the following year',
#      'timestamp': '2020-12-30T13:05:52.649317'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'zlqKs3YB9GIGtQkyR_uU',
#     '_score': 1.0,
#     '_source': {'original_text': 'In July 2014 , Fernandez opened a restaurant in Colombo , <unk> Sutra , in collaboration with chef <unk> <unk> , which specialises in contemporary Sri Lankan cuisine . \n',
#      'text': 'in july 2014 fernandez opened a restaurant in colombo < unk > sutra in collaboration with chef < unk > < unk > which specialises in contemporary sri lankan cuisine',
#      'timestamp': '2020-12-30T13:05:52.659706'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'z1qKs3YB9GIGtQkyR_ul',
#     '_score': 1.0,
#     '_source': {'original_text': ' =',
#      'text': '=',
#      'timestamp': '2020-12-30T13:05:52.676434'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '0FqKs3YB9GIGtQkyR_uv',
#     '_score': 1.0,
#     '_source': {'original_text': '=',
#      'text': '=',
#      'timestamp': '2020-12-30T13:05:52.687024'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '0VqKs3YB9GIGtQkyR_u6',
#     '_score': 1.0,
#     '_source': {'original_text': 'In the media = = \n',
#      'text': 'in the media = =',
#      'timestamp': '2020-12-30T13:05:52.697511'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '0lqKs3YB9GIGtQkyR_vY',
#     '_score': 1.0,
#     '_source': {'original_text': ' In the early 2013 , Fernandez became the ambassador for HTC One , which she endorses in India .',
#      'text': 'in the early 2013 fernandez became the ambassador for htc one which she endorses in india',
#      'timestamp': '2020-12-30T13:05:52.727387'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '01qKs3YB9GIGtQkyR_vi',
#     '_score': 1.0,
#     '_source': {'original_text': 'She was the face of Indian Bridal Fashion Week — <unk> of 2013 .',
#      'text': 'she was the face of indian bridal fashion week — < unk > of 2013',
#      'timestamp': '2020-12-30T13:05:52.737758'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '1FqKs3YB9GIGtQkyR_vs',
#     '_score': 1.0,
#     '_source': {'original_text': "Later that year , she became the spokesperson for Gareth Pugh 's designed <unk> Diamonds in Mumbai , and was at the inaugural opening of the Forever 21 store in Mumbai .",
#      'text': "later that year she became the spokesperson for gareth pugh 's designed < unk > diamonds in mumbai and was at the inaugural opening of the forever 21 store in mumbai",
#      'timestamp': '2020-12-30T13:05:52.748239'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '1VqKs3YB9GIGtQkyR_v3',
#     '_score': 1.0,
#     '_source': {'original_text': 'That year , she also launched Gillette Shaving System with Arbaaz Khan and Aditya Roy Kapur .',
#      'text': 'that year she also launched gillette shaving system with arbaaz khan and aditya roy kapur',
#      'timestamp': '2020-12-30T13:05:52.758484'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '1lqKs3YB9GIGtQkySPsC',
#     '_score': 1.0,
#     '_source': {'original_text': 'While analysing Fernandez \'s career , India TV noted : " Slowly and steadily Jacqueline Fernandez is climbing up the ladder of success [ ... ]',
#      'text': "while analysing fernandez 's career india tv noted slowly and steadily jacqueline fernandez is climbing up the ladder of success [ ... ]",
#      'timestamp': '2020-12-30T13:05:52.770239'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '11qKs3YB9GIGtQkySPsO',
#     '_score': 1.0,
#     '_source': {'original_text': 'Jacqueline is comfortably grasping every aspect of the work , which an actress is required to do and is accordingly giving results .',
#      'text': 'jacqueline is comfortably grasping every aspect of the work which an actress is required to do and is accordingly giving results',
#      'timestamp': '2020-12-30T13:05:52.781830'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '2FqKs3YB9GIGtQkySPsZ',
#     '_score': 1.0,
#     '_source': {'original_text': '" On the contrary , Charu Thakur of India Today criticized her acting skills , but remarked that : " [ she has ] managed to find her feet in Bollywood now by banking on glamorous roles " . \n',
#      'text': 'on the contrary charu thakur of india today criticized her acting skills but remarked that [ she has ] managed to find her feet in bollywood now by banking on glamorous roles',
#      'timestamp': '2020-12-30T13:05:52.793353'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '2VqKs3YB9GIGtQkySPs5',
#     '_score': 1.0,
#     '_source': {'original_text': ' In 2008 and 2011 , Fernandez featured in the UK magazine Eastern Eye \'s " World \'s Sexiest Asian Women " list , ranking twelfth .',
#      'text': "in 2008 and 2011 fernandez featured in the uk magazine eastern eye 's world 's sexiest asian women list ranking twelfth",
#      'timestamp': '2020-12-30T13:05:52.824671'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '2lqKs3YB9GIGtQkySPtF',
#     '_score': 1.0,
#     '_source': {'original_text': 'She was ranked third on The Times of India \'s listing of the " Most Desirable Woman " in 2013 and 2014 , after being ranked eighth , seventh and fourteenth , respectively , in the preceding three years .',
#      'text': "she was ranked third on the times of india 's listing of the most desirable woman in 2013 and 2014 after being ranked eighth seventh and fourteenth respectively in the preceding three years",
#      'timestamp': '2020-12-30T13:05:52.836461'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '21qKs3YB9GIGtQkySPtQ',
#     '_score': 1.0,
#     '_source': {'original_text': 'In 2013 , Rediff.com placed her on their list of " Bollywood \'s Best Dressed Actresses " .',
#      'text': "in 2013 rediff.com placed her on their list of bollywood 's best dressed actresses",
#      'timestamp': '2020-12-30T13:05:52.848199'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '3FqKs3YB9GIGtQkySPtc',
#     '_score': 1.0,
# ...
#     '_id': 'K1qKs3YB9GIGtQkyd_-e',
#     '_score': 1.0,
#     '_source': {'original_text': 'Another milestone in the development of GA was the 1964 introduction of the Learjet 23 .',
#      'text': 'another milestone in the development of ga was the 1964 introduction of the learjet 23',
#      'timestamp': '2020-12-30T13:06:04.958136'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LFqKs3YB9GIGtQkyd_-p',
#     '_score': 1.0,
#     '_source': {'original_text': 'Although it was not the first business jet , it popularised corporate aviation , and established the personal jet as a " whole new class of aircraft " . \n',
#      'text': 'although it was not the first business jet it popularised corporate aviation and established the personal jet as a whole new class of aircraft',
#      'timestamp': '2020-12-30T13:06:04.968563'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LVqKs3YB9GIGtQkyd_-6',
#     '_score': 1.0,
#     '_source': {'original_text': ' = =',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:06:04.985723'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LlqKs3YB9GIGtQkyd__I',
#     '_score': 1.0,
#     '_source': {'original_text': 'Activities = = \n',
#      'text': 'activities = =',
#      'timestamp': '2020-12-30T13:06:04.999633'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'L1qKs3YB9GIGtQkyd__j',
#     '_score': 1.0,
#     '_source': {'original_text': ' The GA sector operates a range of aircraft , including balloons and airships , gliders , hang gliders , paragliders , microlights , <unk> , helicopters , amateur built and mass @-@ produced light aircraft , ex @-@ military aircraft , and business jets .',
#      'text': 'the ga sector operates a range of aircraft including balloons and airships gliders hang gliders paragliders microlights < unk > helicopters amateur built and mass @-@ produced light aircraft ex @-@ military aircraft and business jets',
#      'timestamp': '2020-12-30T13:06:05.026305'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'MFqKs3YB9GIGtQkyd__t',
#     '_score': 1.0,
#     '_source': {'original_text': 'Flights can be broadly categorised as public transport , aerial work , and private flying , the first two of which are commercial activities . \n',
#      'text': 'flights can be broadly categorised as public transport aerial work and private flying the first two of which are commercial activities',
#      'timestamp': '2020-12-30T13:06:05.037039'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'MVqKs3YB9GIGtQkyd__9',
#     '_score': 1.0,
#     '_source': {'original_text': ' = =',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:06:05.053008'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'MlqKs3YB9GIGtQkyeP8I',
#     '_score': 1.0,
#     '_source': {'original_text': '=',
#      'text': '=',
#      'timestamp': '2020-12-30T13:06:05.063619'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'M1qKs3YB9GIGtQkyeP8S',
#     '_score': 1.0,
#     '_source': {'original_text': 'Commercial operations = = = \n',
#      'text': 'commercial operations = = =',
#      'timestamp': '2020-12-30T13:06:05.074097'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'NFqKs3YB9GIGtQkyeP82',
#     '_score': 1.0,
#     '_source': {'original_text': ' Commercial operations are remunerated activities which fall within the ICAO definition of CAT .',
#      'text': 'commercial operations are remunerated activities which fall within the icao definition of cat',
#      'timestamp': '2020-12-30T13:06:05.110067'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'NVqKs3YB9GIGtQkyeP9B',
#     '_score': 1.0,
#     '_source': {'original_text': 'Some are , however , closely aligned to , and considered part of , the GA sector .',
#      'text': 'some are however closely aligned to and considered part of the ga sector',
#      'timestamp': '2020-12-30T13:06:05.120661'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'NlqKs3YB9GIGtQkyeP9L',
#     '_score': 1.0,
#     '_source': {'original_text': 'Public transport operations are non @-@ scheduled , on @-@ demand services flying between points specified by the customer , providing a more flexible service than airline travel .',
#      'text': 'public transport operations are non @-@ scheduled on @-@ demand services flying between points specified by the customer providing a more flexible service than airline travel',
#      'timestamp': '2020-12-30T13:06:05.131187'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'N1qKs3YB9GIGtQkyeP9X',
#     '_score': 1.0,
#     '_source': {'original_text': 'Air taxi operations offer charter services for third parties , and business or corporate aviation uses company @-@ owned aircraft to transport employees and clients .',
#      'text': 'air taxi operations offer charter services for third parties and business or corporate aviation uses company @-@ owned aircraft to transport employees and clients',
#      'timestamp': '2020-12-30T13:06:05.142869'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'OFqKs3YB9GIGtQkyeP9j',
#     '_score': 1.0,
#     '_source': {'original_text': 'Aircraft used in these operations include business jets , helicopters , and twin piston @-@ engine aeroplanes carrying between six and ten people .',
#      'text': 'aircraft used in these operations include business jets helicopters and twin piston @-@ engine aeroplanes carrying between six and ten people',
#      'timestamp': '2020-12-30T13:06:05.154590'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'OVqKs3YB9GIGtQkyeP9u',
#     '_score': 1.0,
#     '_source': {'original_text': 'An example of this type of operation is the transport by helicopter of spectators to the British Formula One grand prix at Silverstone .',
#      'text': 'an example of this type of operation is the transport by helicopter of spectators to the british formula one grand prix at silverstone',
#      'timestamp': '2020-12-30T13:06:05.166330'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'OlqKs3YB9GIGtQkyeP96',
#     '_score': 1.0,
#     '_source': {'original_text': "This involves so many flights that , according to Cranfield Aviation Services , on race day the heliport is temporarily the world 's busiest airport .",
#      'text': "this involves so many flights that according to cranfield aviation services on race day the heliport is temporarily the world 's busiest airport",
#      'timestamp': '2020-12-30T13:06:05.177927'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'O1qKs3YB9GIGtQkyeP-G',
#     '_score': 1.0,
#     '_source': {'original_text': 'Aerial work is a small but important component of the commercial GA sector , characterised in its simplest form as remunerated non @-@ transport activities , such as surveying , crop spraying , and emergency services work ( air ambulance and police ) . \n',
#      'text': 'aerial work is a small but important component of the commercial ga sector characterised in its simplest form as remunerated non @-@ transport activities such as surveying crop spraying and emergency services work ( air ambulance and police )',
#      'timestamp': '2020-12-30T13:06:05.189540'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'PFqKs3YB9GIGtQkyeP-Y',
#     '_score': 1.0,
#     '_source': {'original_text': ' = =',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:06:05.207689'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'PVqKs3YB9GIGtQkyeP-k',
#     '_score': 1.0,
#     '_source': {'original_text': '=',
#      'text': '=',
#      'timestamp': '2020-12-30T13:06:05.219760'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'PlqKs3YB9GIGtQkyeP-w',
#     '_score': 1.0,
#     '_source': {'original_text': 'Flying schools = = = \n',
#      'text': 'flying schools = = =',
#      'timestamp': '2020-12-30T13:06:05.231387'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'P1qKs3YB9GIGtQkyeP_Z',
#     '_score': 1.0,
#     '_source': {'original_text': ' Flying schools are commercial businesses engaged in the training of pilots , both for recreational purposes and for those intending to fly professionally .',
#      'text': 'flying schools are commercial businesses engaged in the training of pilots both for recreational purposes and for those intending to fly professionally',
#      'timestamp': '2020-12-30T13:06:05.272738'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'QFqKs3YB9GIGtQkyeP_l',
#     '_score': 1.0,
#     '_source': {'original_text': 'They make widespread use of fixed @-@ wing light aircraft associated with traditional GA , not only for flying lessons but also as club aircraft rented out to qualified pilots for recreational flights .',
#      'text': 'they make widespread use of fixed @-@ wing light aircraft associated with traditional ga not only for flying lessons but also as club aircraft rented out to qualified pilots for recreational flights',
#      'timestamp': '2020-12-30T13:06:05.284584'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'QVqKs3YB9GIGtQkyeP_x',
#     '_score': 1.0,
#     '_source': {'original_text': 'School @-@ owned aircraft account for a significant amount of GA activity , both in terms of hours flown and aircraft movements .',
#      'text': 'school @-@ owned aircraft account for a significant amount of ga activity both in terms of hours flown and aircraft movements',
#      'timestamp': '2020-12-30T13:06:05.296282'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'QlqKs3YB9GIGtQkyeP_7',
#     '_score': 1.0,
#     '_source': {'original_text': 'The pilot training element is regarded by the GA community as a key benefit that is critical to the supply of pilots for the airline industry .',
#      'text': 'the pilot training element is regarded by the ga community as a key benefit that is critical to the supply of pilots for the airline industry',
#      'timestamp': '2020-12-30T13:06:05.306784'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Q1qKs3YB9GIGtQkyef8F',
#     '_score': 1.0,
#     '_source': {'original_text': 'It is claimed by the General Aviation Awareness Council that 60 – 70 per cent of professional pilots have self @-@ financed their flight training at GA schools , and one UK airline operator has stated that the industry must rely on 70 – 80 per cent of new pilots coming from the GA sector .',
#      'text': 'it is claimed by the general aviation awareness council that 60 – 70 per cent of professional pilots have self @-@ financed their flight training at ga schools and one uk airline operator has stated that the industry must rely on 70 – 80 per cent of new pilots coming from the ga sector',
#      'timestamp': '2020-12-30T13:06:05.317252'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'RFqKs3YB9GIGtQkyef8Q',
#     '_score': 1.0,
#     '_source': {'original_text': 'The CAA estimates that between 1996 and 2006 the number of new professional pilots following the unsponsored training route rose from 48 per cent to 59 per cent .',
#      'text': 'the caa estimates that between 1996 and 2006 the number of new professional pilots following the unsponsored training route rose from 48 per cent to 59 per cent',
#      'timestamp': '2020-12-30T13:06:05.327791'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'RVqKs3YB9GIGtQkyef8a',
#     '_score': 1.0,
#     '_source': {'original_text': 'The counter argument to this claim is that pilots can be trained outside of the UK , and that the airline industry is not therefore dependent on a healthy GA sector in the UK for its supply of pilots .',
#      'text': 'the counter argument to this claim is that pilots can be trained outside of the uk and that the airline industry is not therefore dependent on a healthy ga sector in the uk for its supply of pilots',
#      'timestamp': '2020-12-30T13:06:05.338155'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'RlqKs3YB9GIGtQkyef8l',
#     '_score': 1.0,
#     '_source': {'original_text': 'The CAA concludes that a severe reduction in GA would give " some merit to the argument that pilot recruitment would be threatened " , but that the data on flying hours " does not support such a gloomy outlook .',
#      'text': 'the caa concludes that a severe reduction in ga would give some merit to the argument that pilot recruitment would be threatened but that the data on flying hours does not support such a gloomy outlook',
#      'timestamp': '2020-12-30T13:06:05.348713'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'R1qKs3YB9GIGtQkyef8v',
#     '_score': 1.0,
#     '_source': {'original_text': '"',
#      'text': '',
#      'timestamp': '2020-12-30T13:06:05.359208'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'SFqKs3YB9GIGtQkyef86',
#     '_score': 1.0,
#     '_source': {'original_text': 'Of course , reliance on other countries for pilot training means that the UK foregoes the economic benefit of the training activity . \n',
#      'text': 'of course reliance on other countries for pilot training means that the uk foregoes the economic benefit of the training activity',
#      'timestamp': '2020-12-30T13:06:05.369630'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'SVqKs3YB9GIGtQkyef9M',
#     '_score': 1.0,
#     '_source': {'original_text': ' = =',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:06:05.387391'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'SlqKs3YB9GIGtQkyef9W',
#     '_score': 1.0,
#     '_source': {'original_text': '=',
#      'text': '=',
#      'timestamp': '2020-12-30T13:06:05.398268'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'S1qKs3YB9GIGtQkyef9h',
#     '_score': 1.0,
#     '_source': {'original_text': 'Private flying =',
#      'text': 'private flying =',
#      'timestamp': '2020-12-30T13:06:05.408649'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'TFqKs3YB9GIGtQkyef9r',
#     '_score': 1.0,
#     '_source': {'original_text': '= = \n',
#      'text': '= =',
#      'timestamp': '2020-12-30T13:06:05.419145'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'TVqKs3YB9GIGtQkyef-F',
#     '_score': 1.0,
#     '_source': {'original_text': ' Private flying can be for both recreational purposes and personal transport , using aircraft that are owned individually , collectively as part of a syndicate , or rented from a flying club .',
#      'text': 'private flying can be for both recreational purposes and personal transport using aircraft that are owned individually collectively as part of a syndicate or rented from a flying club',
#      'timestamp': '2020-12-30T13:06:05.444623'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'TlqKs3YB9GIGtQkyef-R',
#     '_score': 1.0,
#     '_source': {'original_text': 'A survey of pilots conducted between 2001 and 2002 indicated that the most common purposes of recreational flights were local flights near the base aerodrome , visits to other aerodromes , and day trips away .',
#      'text': 'a survey of pilots conducted between 2001 and 2002 indicated that the most common purposes of recreational flights were local flights near the base aerodrome visits to other aerodromes and day trips away',
#      'timestamp': '2020-12-30T13:06:05.456422'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'T1qKs3YB9GIGtQkyef-c',
#     '_score': 1.0,
#     '_source': {'original_text': 'Half of all flights landed at the same aerodrome they departed from , and only 9 per cent involved an overnight stay away from home . \n',
#      'text': 'half of all flights landed at the same aerodrome they departed from and only 9 per cent involved an overnight stay away from home',
#      'timestamp': '2020-12-30T13:06:05.468138'}}]}}

# %% [markdown]
# Query example

# %%
q = '''{
  "query": {
    "match": {
      "text": "game"
    }
  }
}'''

# %%
es.search(body = q, index=ES_INDEX, size=ES_QUERY_SIZE)
# Out:
# {'took': 610,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 7.0213437,
#   'hits': [{'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'bmc8tHYB9GIGtQkyQWPl',
#     '_score': 7.0213437,
#     '_source': {'original_text': 'Game Critics also named the game " Best Action Game . "',
#      'text': 'game critics also named the game best action game',
#      'timestamp': '2020-12-30T16:20:16.613220'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'PGpntHYB9GIGtQkyRFy0',
#     '_score': 7.0024157,
#     '_source': {'original_text': 'The Game ( mind game ) = \n',
#      'text': 'the game ( mind game ) =',
#      'timestamp': '2020-12-30T17:07:15.379597'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'lYpvtnYB9GIGtQky2-_U',
#     '_score': 6.900861,
#     '_source': {'original_text': 'The game was named " Best Original Game " and " Best Handheld Game " by the Game Critics Awards .',
#      'text': 'the game was named best original game and best handheld game by the game critics awards',
#      'timestamp': '2020-12-31T02:35:52.788147'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'nm6gtHYB9GIGtQkyzzs4',
#     '_score': 6.8734694,
#     '_source': {'original_text': 'PC game Animaniacs Game Pack !',
#      'text': 'pc game animaniacs game pack',
#      'timestamp': '2020-12-30T18:10:06.391668'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'r5LutnYB9GIGtQky8b0G',
#     '_score': 6.780901,
#     '_source': {'original_text': 'Other individual awards include " Best Action / Adventure Game " ( Game Trailers ) , " Best Action Game " ( GameSpy ) , " Best PS3 Game " ( Game Revolution ) , and " Best PS3 Exclusive " ( Shacknews ) .',
#      'text': 'other individual awards include best action / adventure game ( game trailers ) best action game ( gamespy ) best ps3 game ( game revolution ) and best ps3 exclusive ( shacknews )',
#      'timestamp': '2020-12-31T04:54:41.286497'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'dZP7tnYB9GIGtQkySYA1',
#     '_score': 6.780901,
#     '_source': {'original_text': 'The game was also chosen as Best Game Boy Advance Adventure Game by IGN and Best Action Game on Game Boy Advance by GameSpot . \n',
#      'text': 'the game was also chosen as best game boy advance adventure game by ign and best action game on game boy advance by gamespot',
#      'timestamp': '2020-12-31T05:08:10.293561'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'wZuCt3YB9GIGtQky0NVw',
#     '_score': 6.766769,
#     '_source': {'original_text': 'Game Critics Awards gave the game Best Action Game of E3 2008 .',
#      'text': 'game critics awards gave the game best action game of e3 2008',
#      'timestamp': '2020-12-31T07:36:12.272214'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'N2c5tHYB9GIGtQkyAiqh',
#     '_score': 6.7146516,
#     '_source': {'original_text': 'A video game named The Itchy & Scratchy Game was released for Genesis , Game Gear , Super NES and Game Boy .',
#      'text': 'a video game named the itchy & scratchy game was released for genesis game gear super nes and game boy',
#      'timestamp': '2020-12-30T16:16:43.809004'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '4mMFtHYB9GIGtQkyGo1a',
#     '_score': 6.7146516,
#     '_source': {'original_text': 'Best in Show , Best Original Game , Best Console Game , Best PC Game , Best Action Game , and Best Online Multiplayer .',
#      'text': 'best in show best original game best console game best pc game best action game and best online multiplayer',
#      'timestamp': '2020-12-30T15:20:02.010543'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'WKQQuHYB9GIGtQky7pLT',
#     '_score': 6.685964,
#     '_source': {'original_text': "Game Informer 's Ben Reeves called it the seventh best Game Boy game . \n",
#      'text': "game informer 's ben reeves called it the seventh best game boy game",
#      'timestamp': '2020-12-31T10:11:26.162579'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'I4DFtXYB9GIGtQkyU38t',
#     '_score': 6.6547947,
#     '_source': {'original_text': 'The game is sometimes referred to as the " 28 @-@ out perfect game " , the " Imperfect Game " , or simply the " Galarraga game " . \n',
#      'text': 'the game is sometimes referred to as the 28 @-@ out perfect game the imperfect game or simply the galarraga game',
#      'timestamp': '2020-12-30T23:29:36.684887'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'voHXtXYB9GIGtQkyrJ6e',
#     '_score': 6.6547947,
#     '_source': {'original_text': 'The game also won the titles " Best PC Game " and " Best Strategy Game " in the 2012 E3 Game Critics Awards . \n',
#      'text': 'the game also won the titles best pc game and best strategy game in the 2012 e3 game critics awards',
#      'timestamp': '2020-12-30T23:49:39.229984'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'T2yBtHYB9GIGtQky2y-l',
#     '_score': 6.6293187,
#     '_source': {'original_text': 'The game features three multiplayer game types :',
#      'text': 'the game features three multiplayer game types',
#      'timestamp': '2020-12-30T17:36:17.957230'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'fnLstHYB9GIGtQkyEvq9',
#     '_score': 6.6293187,
#     '_source': {'original_text': 'Based Game , and Best Super NES Game .',
#      'text': 'based game and best super nes game',
#      'timestamp': '2020-12-30T19:32:18.877070'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'OqUjuHYB9GIGtQkyo7gd',
#     '_score': 6.6293187,
#     '_source': {'original_text': "Game She 's Got Game Award : 2012 \n",
#      'text': "game she 's got game award 2012",
#      'timestamp': '2020-12-31T10:31:51.964538'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'uHT9tHYB9GIGtQkytxVU',
#     '_score': 6.607066,
#     '_source': {'original_text': 'At Spike , the game won awards for " Best Wii Game " and " Best Motion Game " .',
#      'text': 'at spike the game won awards for best wii game and best motion game',
#      'timestamp': '2020-12-30T19:51:35.123743'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '6nt7tXYB9GIGtQkyiu_8',
#     '_score': 6.607066,
#     '_source': {'original_text': ' The game has been called both a platform game and an action @-@ adventure game .',
#      'text': 'the game has been called both a platform game and an action @-@ adventure game',
#      'timestamp': '2020-12-30T22:09:01.308100'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xoHWtXYB9GIGtQkyMIf9',
#     '_score': 6.607066,
#     '_source': {'original_text': 'The game won for Best Music Game on the Spike Video Game Awards 2009 .',
#      'text': 'the game won for best music game on the spike video game awards 2009',
#      'timestamp': '2020-12-30T23:48:02.045191'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'p42ctnYB9GIGtQkyfKpS',
#     '_score': 6.595996,
#     '_source': {'original_text': "Game Informer 's Ben Reeves called it the 14th best Game Boy game and felt that it was a relaxing game .",
#      'text': "game informer 's ben reeves called it the 14th best game boy game and felt that it was a relaxing game",
#      'timestamp': '2020-12-31T03:24:37.458236'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'vpHhtnYB9GIGtQky_vIm',
#     '_score': 6.5818176,
#     '_source': {'original_text': "Zero Mission was voted IGN 's Game Boy Advance Game of the Month for February 2004 , and the website 's staff picked the game as both the Best Game Boy Adventure Game of 2004 , and the 9th Best Game Boy Advance Game .",
#      'text': "zero mission was voted ign 's game boy advance game of the month for february 2004 and the website 's staff picked the game as both the best game boy adventure game of 2004 and the 9th best game boy advance game",
#      'timestamp': '2020-12-31T04:40:32.677663'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'F12ss3YB9GIGtQkyEj17',
#     '_score': 6.5464664,
#     '_source': {'original_text': 'Eurogamer \'s Kristan Reed was keenly aware of the game \'s limited appeal , calling it " a concept game , an arthouse game , a simple game , an often beautiful game , but most certainly never an everyman \'s game " .',
#      'text': "eurogamer 's kristan reed was keenly aware of the game 's limited appeal calling it a concept game an arthouse game a simple game an often beautiful game but most certainly never an everyman 's game",
#      'timestamp': '2020-12-30T13:42:47.290908'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'YX2TtXYB9GIGtQky1nPf',
#     '_score': 6.538227,
#     '_source': {'original_text': "One Game , Best PlayStation 4 Game , Best PC Game , and Best Action Game at the IGN 's Best of E3 2014 Awards .",
#      'text': "one game best playstation 4 game best pc game and best action game at the ign 's best of e3 2014 awards",
#      'timestamp': '2020-12-30T22:35:33.598906'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'IH-utXYB9GIGtQkybhbA',
#     '_score': 6.538227,
#     '_source': {'original_text': 'Game Players gave it the titles of " Best Genesis Fighting Game " , " Best SNES Fighting Game " and " Best Overall SNES Game " of 1994 .',
#      'text': 'game players gave it the titles of best genesis fighting game best snes fighting game and best overall snes game of 1994',
#      'timestamp': '2020-12-30T23:04:36.416573'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'XmUctHYB9GIGtQkyJygi',
#     '_score': 6.530009,
#     '_source': {'original_text': 'The game won the " Best Handheld Game " award in the 2011 Spike Video Game Awards .',
#      'text': 'the game won the best handheld game award in the 2011 spike video game awards',
#      'timestamp': '2020-12-30T15:45:12.609867'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '52MFtHYB9GIGtQkyGo2N',
#     '_score': 6.530009,
#     '_source': {'original_text': 'The game won Best Next Generation Console Game and Best Xbox Game at Gamescom 2013 .',
#      'text': 'the game won best next generation console game and best xbox game at gamescom 2013',
#      'timestamp': '2020-12-30T15:20:02.061511'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'DoHWtXYB9GIGtQkyUoqX',
#     '_score': 6.530009,
#     '_source': {'original_text': 'At the 2003 Game Critics Awards , the game was awarded as " Best Action / Adventure Game " .',
#      'text': 'at the 2003 game critics awards the game was awarded as best action / adventure game',
#      'timestamp': '2020-12-30T23:48:10.646659'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'm2pmtHYB9GIGtQkyE0iV',
#     '_score': 6.530009,
#     '_source': {'original_text': 'The game was considered the Best Console Game by the Game Critics Awards and GameSpy .',
#      'text': 'the game was considered the best console game by the game critics awards and gamespy',
#      'timestamp': '2020-12-30T17:05:57.269485'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'R2pntHYB9GIGtQkyZF4O',
#     '_score': 6.530009,
#     '_source': {'original_text': 'adventure video game developed and published by Nintendo for the Game Boy handheld game console .',
#      'text': 'adventure video game developed and published by nintendo for the game boy handheld game console',
#      'timestamp': '2020-12-30T17:07:23.406301'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mIpvtnYB9GIGtQky2-_8',
#     '_score': 6.530009,
#     '_source': {'original_text': 'X @-@ Play gave the game its E3 " Best Original Game " and " Best Handheld Game " awards .',
#      'text': 'x @-@ play gave the game its e3 best original game and best handheld game awards',
#      'timestamp': '2020-12-31T02:35:52.828010'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'aJlft3YB9GIGtQkyR6V3',
#     '_score': 6.530009,
#     '_source': {'original_text': 'Game Informer named the game its Handheld Game of the Month award for May 2008 .',
#      'text': 'game informer named the game its handheld game of the month award for may 2008',
#      'timestamp': '2020-12-31T06:57:23.447165'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'kJlkt3YB9GIGtQkyRfPh',
#     '_score': 6.530009,
#     '_source': {'original_text': ' Once the game is completed , a new game plus mode is available called " EX game " .',
#      'text': 'once the game is completed a new game plus mode is available called ex game',
#      'timestamp': '2020-12-31T07:02:50.721031'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'U5t2t3YB9GIGtQkymBWW',
#     '_score': 6.530009,
#     '_source': {'original_text': 'IGN , Game Informer , GamesRadar , and Game Trailers all criticized the backtracking needed in the game .',
#      'text': 'ign game informer gamesradar and game trailers all criticized the backtracking needed in the game',
#      'timestamp': '2020-12-31T07:22:51.542474'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'fVycs3YB9GIGtQkylx2S',
#     '_score': 6.5136337,
#     '_source': {'original_text': '@-@ breaker game was a one @-@ game extension to',
#      'text': '@-@ breaker game was a one @-@ game extension to',
#      'timestamp': '2020-12-30T13:25:52.786170'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '1mMDtHYB9GIGtQkyXG-t',
#     '_score': 6.5136337,
#     '_source': {'original_text': 'In the championship game , Streets had a game @-@',
#      'text': 'in the championship game streets had a game @-@',
#      'timestamp': '2020-12-30T15:18:07.917314'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'IIDJtXYB9GIGtQkyn8MQ',
#     '_score': 6.5136337,
#     '_source': {'original_text': ' The game features five single @-@ player game modes :',
#      'text': 'the game features five single @-@ player game modes',
#      'timestamp': '2020-12-30T23:34:18.255928'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'TW2ZtHYB9GIGtQkys8P1',
#     '_score': 6.5136337,
#     '_source': {'original_text': 'The game modes featured in the game include : \n',
#      'text': 'the game modes featured in the game include',
#      'timestamp': '2020-12-30T18:02:20.660813'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'TXPztHYB9GIGtQkyAW5r',
#     '_score': 6.5136337,
#     '_source': {'original_text': 'em up game with role @-@ playing game elements .',
#      'text': 'em up game with role @-@ playing game elements',
#      'timestamp': '2020-12-30T19:39:53.195189'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'M6Hdt3YB9GIGtQkyBWHG',
#     '_score': 6.5136337,
#     '_source': {'original_text': 'Game Critics Awards gave the game " Best Role @-@',
#      'text': 'game critics awards gave the game best role @-@',
#      'timestamp': '2020-12-31T09:14:44.166078'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'd5P7tnYB9GIGtQkySYBb',
#     '_score': 6.497608,
#     '_source': {'original_text': 'Video game magazine Game Informer agreed , describing the game as " everything you could want from a Game Boy Advance game " from beginning to end , giving it a perfect review score .',
#      'text': 'video game magazine game informer agreed describing the game as everything you could want from a game boy advance game from beginning to end giving it a perfect review score',
#      'timestamp': '2020-12-31T05:08:10.331408'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Yn2TtXYB9GIGtQky1nPq',
#     '_score': 6.4814615,
#     '_source': {'original_text': 'Similarly , at the 2014 Game Critics Awards , the game was nominated for Best of Show , Best Console Game , and Best Action / Adventure Game .',
#      'text': 'similarly at the 2014 game critics awards the game was nominated for best of show best console game and best action / adventure game',
#      'timestamp': '2020-12-30T22:35:33.610296'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'UI-2tnYB9GIGtQkygkUK',
#     '_score': 6.4814615,
#     '_source': {'original_text': 'Evolve was also named the Best Game , Best Console Game Microsoft Xbox , Best PC Game and Best Online Multiplayer Game at Gamescom 2014 .',
#      'text': 'evolve was also named the best game best console game microsoft xbox best pc game and best online multiplayer game at gamescom 2014',
#      'timestamp': '2020-12-31T03:53:02.857675'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'rJdBt3YB9GIGtQky-9dr',
#     '_score': 6.4814615,
#     '_source': {'original_text': 'At the 2011 Canadian Videogame Awards , the game was awarded Game of the Year , Best Console Game , Best Game Design , and Best Writing .',
#      'text': 'at the 2011 canadian videogame awards the game was awarded game of the year best console game best game design and best writing',
#      'timestamp': '2020-12-31T06:25:23.435198'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LYLktXYB9GIGtQkyeGcF',
#     '_score': 6.470808,
#     '_source': {'original_text': 'These nominations included " Best Action / Adventure " and " Best Multiplayer " from Game Rant , " Best PS3 Game " and " Best Action / Adventure Game " from G4 , " Best PlayStation 3 Game " from Destructoid , and " Best PS3 Game " and " Best Action Game " from IGN .',
#      'text': 'these nominations included best action / adventure and best multiplayer from game rant best ps3 game and best action / adventure game from g4 best playstation 3 game from destructoid and best ps3 game and best action game from ign',
#      'timestamp': '2020-12-31T00:03:37.733096'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'G2Hrs3YB9GIGtQky6ckd',
#     '_score': 6.4649982,
#     '_source': {'original_text': ' = = = = = Game = = = = = \n',
#      'text': '= = = = = game = = = = =',
#      'timestamp': '2020-12-30T14:52:31.004578'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Z2Dcs3YB9GIGtQkyH6wn',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-30T14:35:16.263224'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LGDes3YB9GIGtQkyJtBV',
#     '_score': 6.4649982,
#     '_source': {'original_text': '> game .',
#      'text': '> game',
#      'timestamp': '2020-12-30T14:37:29.173096'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mnpjtXYB9GIGtQkyqnLo',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game .',
#      'text': 'game',
#      'timestamp': '2020-12-30T21:42:56.616329'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'p36gtXYB9GIGtQkyszxo',
#     '_score': 6.4649982,
#     '_source': {'original_text': ' = = = Game = = = \n',
#      'text': '= = = game = = =',
#      'timestamp': '2020-12-30T22:49:36.487449'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'r3-utXYB9GIGtQkyZxWx',
#     '_score': 6.4649982,
#     '_source': {'original_text': ' = = = Game = = = \n',
#      'text': '= = = game = = =',
#      'timestamp': '2020-12-30T23:04:34.608459'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'gl6-s3YB9GIGtQky_pmD',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game = = \n',
#      'text': 'game = =',
#      'timestamp': '2020-12-30T14:03:27.363480'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'HnHXtHYB9GIGtQkydrCX',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-30T19:09:48.183389'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Q3HXtHYB9GIGtQkyeLDC',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-30T19:09:48.738316'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'pHPvtHYB9GIGtQky_TzU',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-30T19:36:35.667833'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '1XPwtHYB9GIGtQkyADyy',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-30T19:36:36.401604'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'FXPwtHYB9GIGtQkyBD0y',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-30T19:36:37.298354'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'TIQItnYB9GIGtQkyiJZd',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T00:43:01.212978'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tILrtXYB9GIGtQkyUsvU',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T00:11:06.963867'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'GopjtnYB9GIGtQkyaivl',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T02:22:17.445204'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'VYpjtnYB9GIGtQkybitx',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T02:22:18.353449'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 't4pqtnYB9GIGtQky5KDE',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game = = \n',
#      'text': 'game = =',
#      'timestamp': '2020-12-31T02:30:27.395622'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mYyLtnYB9GIGtQkyAZjn',
#     '_score': 6.4649982,
#     '_source': {'original_text': ' = = = Game = = = \n',
#      'text': '= = = game = = =',
#      'timestamp': '2020-12-31T03:05:32.006804'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '8oyPtnYB9GIGtQkyTNsd',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T03:10:13.148914'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'QoyPtnYB9GIGtQkyUNyk',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T03:10:14.308217'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '7YyPtnYB9GIGtQkyWtwH',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T03:10:16.711003'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Ko6ttnYB9GIGtQky-72P',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T03:43:44.143308'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'oZ6ut3YB9GIGtQkyc4bh',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game',
#      'text': 'game',
#      'timestamp': '2020-12-31T08:23:52.161253'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'aKLot3YB9GIGtQkyYRUt',
#     '_score': 6.4649982,
#     '_source': {'original_text': 'Game = = \n',
#      'text': 'game = =',
#      'timestamp': '2020-12-31T09:27:08.461078'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'HWP-s3YB9GIGtQky-iH6',
#     '_score': 6.454728,
#     '_source': {'original_text': 'This made the game the tenth game for a Nintendo DS game to earn the rating .',
#      'text': 'this made the game the tenth game for a nintendo ds game to earn the rating',
#      'timestamp': '2020-12-30T15:13:20.761803'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '04pvtnYB9GIGtQky3--R',
#     '_score': 6.454728,
#     '_source': {'original_text': 'The game won " Innovation " and " Best Handheld Game " at the 10th annual Game Developers Choice Awards . \n',
#      'text': 'the game won innovation and best handheld game at the 10th annual game developers choice awards',
#      'timestamp': '2020-12-31T02:35:53.744958'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 't56ut3YB9GIGtQkyZoVK',
#     '_score': 6.454728,
#     '_source': {'original_text': 'The game also won " Best Fighting Game " in GameSpot \'s Game of the Year awards 2008 .',
#      'text': "the game also won best fighting game in gamespot 's game of the year awards 2008",
#      'timestamp': '2020-12-31T08:23:48.682257'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'wZUct3YB9GIGtQky1I-2',
#     '_score': 6.452678,
#     '_source': {'original_text': '" It received several awards at E3 2010 including " Best Handheld Game " , " Best PSP Game " , and " PSP Game of Show " , and won " Best Handheld Game " at the 2010 Spike Video Game Awards . \n',
#      'text': 'it received several awards at e3 2010 including best handheld game best psp game and psp game of show and won best handheld game at the 2010 spike video game awards',
#      'timestamp': '2020-12-31T05:44:48.694310'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Kn-ttXYB9GIGtQkyuAv5',
#     '_score': 6.452678,
#     '_source': {'original_text': 'The game won Game of the Year from Classic Game Room , received nominations from the Golden Joystick Awards , Good Game Game Informer , and IGN Australia , and received runner @-@ up from Polygon .',
#      'text': 'the game won game of the year from classic game room received nominations from the golden joystick awards good game game informer and ign australia and received runner @-@ up from polygon',
#      'timestamp': '2020-12-30T23:03:49.881496'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ZqHkt3YB9GIGtQkyaNVV',
#     '_score': 6.452678,
#     '_source': {'original_text': '" It received several awards at E3 2010 including " Best Handheld Game " , " Best PSP Game " , and " PSP Game of Show " , and won " Best Handheld Game " at the 2010 Spike Video Game Awards . \n',
#      'text': 'it received several awards at e3 2010 including best handheld game best psp game and psp game of show and won best handheld game at the 2010 spike video game awards',
#      'timestamp': '2020-12-31T09:22:48.149182'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '3KP4t3YB9GIGtQky4hcd',
#     '_score': 6.452678,
#     '_source': {'original_text': 'No One Played " and Kristan Reed of Eurogamer called it " a concept game , an arthouse game , a simple game , an often beautiful game , but most certainly never an everyman \'s game " . \n',
#      'text': "no one played and kristan reed of eurogamer called it a concept game an arthouse game a simple game an often beautiful game but most certainly never an everyman 's game",
#      'timestamp': '2020-12-31T09:45:10.045304'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'j3lNtXYB9GIGtQkyzxD2',
#     '_score': 6.4256725,
#     '_source': {'original_text': 'Game designer Sandy Petersen reviewed the game in Dragon , and described the game as much like Zelda but with conventional role @-@ playing game features .',
#      'text': 'game designer sandy petersen reviewed the game in dragon and described the game as much like zelda but with conventional role @-@ playing game features',
#      'timestamp': '2020-12-30T21:19:04.309634'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'K26ntHYB9GIGtQky7rEO',
#     '_score': 6.4256725,
#     '_source': {'original_text': ' At the 2010 Game Developers Conference , Zynga \'s game FarmVille was awarded the " Best New Social / Online Game " at its Game Developers Choice Awards .',
#      'text': "at the 2010 game developers conference zynga 's game farmville was awarded the best new social / online game at its game developers choice awards",
#      'timestamp': '2020-12-30T18:17:53.038237'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'To-2tnYB9GIGtQkygUXz',
#     '_score': 6.4083652,
#     '_source': {'original_text': 'It was nominated for six different awards in the Game Critics Awards , namely Best of Show , Best Original Game , Best Console Game , Best PC Game , Best Action Game and Best Online Multiplayer .',
#      'text': 'it was nominated for six different awards in the game critics awards namely best of show best original game best console game best pc game best action game and best online multiplayer',
#      'timestamp': '2020-12-31T03:53:02.834787'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'z3latXYB9GIGtQkyTNvq',
#     '_score': 6.4019175,
#     '_source': {'original_text': ' This game turned out to be the last game .',
#      'text': 'this game turned out to be the last game',
#      'timestamp': '2020-12-30T21:32:42.729930'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LmP-s3YB9GIGtQkyBA-2',
#     '_score': 6.4019175,
#     '_source': {'original_text': 'The game features interactivity with the Game Boy Advance .',
#      'text': 'the game features interactivity with the game boy advance',
#      'timestamp': '2020-12-30T15:12:17.718220'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'kG6ktHYB9GIGtQkyy34e',
#     '_score': 6.4019175,
#     '_source': {'original_text': 'Video game magazine Game Informer praised Silent Hill 4 :',
#      'text': 'video game magazine game informer praised silent hill 4',
#      'timestamp': '2020-12-30T18:14:27.485994'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '7HhCtXYB9GIGtQkyVFnQ',
#     '_score': 6.4019175,
#     '_source': {'original_text': ' The game offers single @-@ player and multiplayer game modes .',
#      'text': 'the game offers single @-@ player and multiplayer game modes',
#      'timestamp': '2020-12-30T21:06:31.888275'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'QG-utHYB9GIGtQkyAhWX',
#     '_score': 6.4019175,
#     '_source': {'original_text': 'Another game was released for the Game Boy Color . \n',
#      'text': 'another game was released for the game boy color',
#      'timestamp': '2020-12-30T18:24:31.510768'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '8HLgtHYB9GIGtQkyBDjr',
#     '_score': 6.4019175,
#     '_source': {'original_text': 'All @-@ Star Game , hitting a double in the game .',
#      'text': 'all @-@ star game hitting a double in the game',
#      'timestamp': '2020-12-30T19:19:08.906652'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'j4LhtXYB9GIGtQkypjq7',
#     '_score': 6.4019175,
#     '_source': {'original_text': 'The game was co @-@ developed by mobile game developer',
#      'text': 'the game was co @-@ developed by mobile game developer',
#      'timestamp': '2020-12-31T00:00:33.082363'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'oKYyuHYB9GIGtQkyDJu9',
#     '_score': 6.4019175,
#     '_source': {'original_text': ' The game was overall well received by game critics .',
#      'text': 'the game was overall well received by game critics',
#      'timestamp': '2020-12-31T10:47:36.508622'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '1WhNtHYB9GIGtQkyY5Q0',
#     '_score': 6.381163,
#     '_source': {'original_text': 'The game was developed at Intelligent Systems , whose previous notable game was the strategy game Famicom Wars .',
#      'text': 'the game was developed at intelligent systems whose previous notable game was the strategy game famicom wars',
#      'timestamp': '2020-12-30T16:38:59.251938'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'YH2TtXYB9GIGtQky1nPS',
#     '_score': 6.381163,
#     '_source': {'original_text': '" The game was awarded Best VR Game and was nominated for Game of the Show , Best Xbox',
#      'text': 'the game was awarded best vr game and was nominated for game of the show best xbox',
#      'timestamp': '2020-12-30T22:35:33.585984'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'PWpntHYB9GIGtQkyRFzL',
#     '_score': 6.381163,
#     '_source': {'original_text': ' The Game is a mental game where the objective is to avoid thinking about The Game itself .',
#      'text': 'the game is a mental game where the objective is to avoid thinking about the game itself',
#      'timestamp': '2020-12-30T17:07:15.403044'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '8pHatnYB9GIGtQkyZnoN',
#     '_score': 6.381163,
#     '_source': {'original_text': "Game Informer 's Ben Reeves called it the third best Game Boy game and called it influential .",
#      'text': "game informer 's ben reeves called it the third best game boy game and called it influential",
#      'timestamp': '2020-12-31T04:32:14.987425'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'I5QLt3YB9GIGtQkydX_t',
#     '_score': 6.381163,
#     '_source': {'original_text': 'GameSpot nominated the game for Game of the Year , and awarded it PS3 Game of the Year .',
#      'text': 'gamespot nominated the game for game of the year and awarded it ps3 game of the year',
#      'timestamp': '2020-12-31T05:25:50.317476'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'OZc5t3YB9GIGtQkygVIn',
#     '_score': 6.381163,
#     '_source': {'original_text': 'In March 2007 , the game was ranked as the 20th best Game Boy Advance game by IGN .',
#      'text': 'in march 2007 the game was ranked as the 20th best game boy advance game by ign',
#      'timestamp': '2020-12-31T06:16:07.847149'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'DZpqt3YB9GIGtQkyklfO',
#     '_score': 6.381163,
#     '_source': {'original_text': 'At E3 1998 it was given Game Critics Awards for " Best PC Game " and " Best Action Game " . \n',
#      'text': 'at e3 1998 it was given game critics awards for best pc game and best action game',
#      'timestamp': '2020-12-31T07:09:43.630024'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ppHetnYB9GIGtQkyirtQ',
#     '_score': 6.3708363,
#     '_source': {'original_text': 'The game includes a built @-@ in rumble functionality into the game cartridge and supports the Game Boy Printer , Game Link Cable , and Transfer Pak accessories .',
#      'text': 'the game includes a built @-@ in rumble functionality into the game cartridge and supports the game boy printer game link cable and transfer pak accessories',
#      'timestamp': '2020-12-31T04:36:46.416397'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'TmhRtHYB9GIGtQkyjd8w',
#     '_score': 6.32154,
#     '_source': {'original_text': ' The game holds an aggregate score of 92 @.@ 11 percent on Game Rankings , coming in as the second best game on the Game Boy Color and the 150th best game overall on its lists .',
#      'text': 'the game holds an aggregate score of 92 @.@ 11 percent on game rankings coming in as the second best game on the game boy color and the 150th best game overall on its lists',
#      'timestamp': '2020-12-30T16:43:32.144122'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'G4DMtXYB9GIGtQkyePCZ',
#     '_score': 6.32154,
#     '_source': {'original_text': 'The International Game Developers Association nominated the title for three honors at the 2004 Game Developers Choice Awards : " Game of the Year " , " Original Game Character of the Year " ( Jade ) and " Excellence in Game Design " .',
#      'text': 'the international game developers association nominated the title for three honors at the 2004 game developers choice awards game of the year original game character of the year ( jade ) and excellence in game design',
#      'timestamp': '2020-12-30T23:37:25.017471'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'C5P7tnYB9GIGtQkyQoD8',
#     '_score': 6.32154,
#     '_source': {'original_text': 'Fusion received several awards , including Handheld Game of the Year at the 2002 Interactive Achievement Awards , Best Game Boy Advance Adventure Game from IGN , and Best Action Game on Game Boy Advance from GameSpot .',
#      'text': 'fusion received several awards including handheld game of the year at the 2002 interactive achievement awards best game boy advance adventure game from ign and best action game on game boy advance from gamespot',
#      'timestamp': '2020-12-31T05:08:08.699785'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'cGc8tHYB9GIGtQkyQWP8',
#     '_score': 6.316928,
#     '_source': {'original_text': 'From the Academy of Interactive Arts & Sciences , the game won Console Game of the Year , Action game of the Year , and Overall Game of the Year .',
#      'text': 'from the academy of interactive arts & sciences the game won console game of the year action game of the year and overall game of the year',
#      'timestamp': '2020-12-30T16:20:16.636085'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'knLgtHYB9GIGtQkybD5_',
#     '_score': 6.316928,
#     '_source': {'original_text': 'It won " Excellence in Game Design " and " Game Innovation Spotlight " at the 2001 Game Developers Choice Awards , and it was nominated for " Game of the Year " .',
#      'text': 'it won excellence in game design and game innovation spotlight at the 2001 game developers choice awards and it was nominated for game of the year',
#      'timestamp': '2020-12-30T19:19:35.422752'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '-XpgtXYB9GIGtQky5kXW',
#     '_score': 6.3092566,
#     '_source': {'original_text': 'The American @-@ based publication Game Informer said that the game is arguably " the best Mario game to date . "',
#      'text': 'the american @-@ based publication game informer said that the game is arguably the best mario game to date',
#      'timestamp': '2020-12-30T21:39:55.349977'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'iJ6zt3YB9GIGtQky2Nru',
#     '_score': 6.3092566,
#     '_source': {'original_text': "The game would become Fez and the game 's design , lore , and art derived from this game mechanic .",
#      'text': "the game would become fez and the game 's design lore and art derived from this game mechanic",
#      'timestamp': '2020-12-31T08:29:45.710409'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '2luWs3YB9GIGtQky9LTp',
#     '_score': 6.2939687,
#     '_source': {'original_text': "all @-@ star game , which was Michael Jordan 's last game .",
#      'text': "all @-@ star game which was michael jordan 's last game",
#      'timestamp': '2020-12-30T13:19:43.465199'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '4mDes3YB9GIGtQky_d8q',
#     '_score': 6.2939687,
#     '_source': {'original_text': ' The aerial game was also developed within the Sheffield game .',
#      'text': 'the aerial game was also developed within the sheffield game',
#      'timestamp': '2020-12-30T14:38:24.169934'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'NnpftXYB9GIGtQkyVivB',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'Prior to game one Shero devised an unconventional game plan .',
#      'text': 'prior to game one shero devised an unconventional game plan',
#      'timestamp': '2020-12-30T21:38:12.928916'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'wXpjtXYB9GIGtQkyBGfj',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'In Game 2 on October 10 , Pujols hit a game @-@',
#      'text': 'in game 2 on october 10 pujols hit a game @-@',
#      'timestamp': '2020-12-30T21:42:14.114611'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'T4URtnYB9GIGtQkyKR33',
#     '_score': 6.2939687,
#     '_source': {'original_text': '> of Game Informer felt that the soundtrack improves the game .',
#      'text': '> of game informer felt that the soundtrack improves the game',
#      'timestamp': '2020-12-31T00:52:26.870846'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'loUbtnYB9GIGtQkywMOK',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'The game offers a few spots to save the game .',
#      'text': 'the game offers a few spots to save the game',
#      'timestamp': '2020-12-31T01:04:00.778224'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mX2ZtXYB9GIGtQkyss-O',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'A Kickoff Game , a game organized by the Chick @-@ fil @-@',
#      'text': 'a kickoff game a game organized by the chick @-@ fil @-@',
#      'timestamp': '2020-12-30T22:41:57.518065'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'X36htXYB9GIGtQkyw05y',
#     '_score': 6.2939687,
#     '_source': {'original_text': '3 points per game and 9 @.@ 9 rebounds per game .',
#      'text': '3 points per game and 9 @.@ 9 rebounds per game',
#      'timestamp': '2020-12-30T22:50:46.130495'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'hH6htXYB9GIGtQkyxk6d',
#     '_score': 6.2939687,
#     '_source': {'original_text': '3 points per game and 5 @.@ 0 rebounds per game .',
#      'text': '3 points per game and 5 @.@ 0 rebounds per game',
#      'timestamp': '2020-12-30T22:50:46.941003'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Ilygs3YB9GIGtQkyoWj7',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'A Video Game Symphony video game music concerts in 2006 .',
#      'text': 'a video game symphony video game music concerts in 2006',
#      'timestamp': '2020-12-30T13:30:17.594765'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'u46jtnYB9GIGtQkyPBV4',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'Statistically , the game counted as the 163rd regular season game .',
#      'text': 'statistically the game counted as the 163rd regular season game',
#      'timestamp': '2020-12-31T03:31:59.863672'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'pJUZt3YB9GIGtQkyZFqP',
#     '_score': 6.2939687,
#     '_source': {'original_text': "The game ended the Athletics ' ten @-@ game postseason win streak .",
#      'text': 'the game ended the athletics ten @-@ game postseason win streak',
#      'timestamp': '2020-12-31T05:41:03.375198'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Y4DJtXYB9GIGtQkypMPj',
#     '_score': 6.2939687,
#     '_source': {'original_text': "The game received G @-@ Phoria 's Best Handheld Game award .",
#      'text': "the game received g @-@ phoria 's best handheld game award",
#      'timestamp': '2020-12-30T23:34:19.746714'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'KW6htHYB9GIGtQkyjki0',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'The game featured updated in @-@ game artwork and new dialogue .',
#      'text': 'the game featured updated in @-@ game artwork and new dialogue',
#      'timestamp': '2020-12-30T18:10:55.412274'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '0HhItXYB9GIGtQky-cT4',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'Game 6 was the third overtime game of the series .',
#      'text': 'game 6 was the third overtime game of the series',
#      'timestamp': '2020-12-30T21:13:47.384032'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'inLstHYB9GIGtQkyE_p1',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'Game Informer called it its 15th favourite game in 2001 .',
#      'text': 'game informer called it its 15th favourite game in 2001',
#      'timestamp': '2020-12-30T19:32:19.061033'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'nWpmtHYB9GIGtQkyE0is',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'IGN ranked the game as the 4th @-@ best Wii game .',
#      'text': 'ign ranked the game as the 4th @-@ best wii game',
#      'timestamp': '2020-12-30T17:05:57.292404'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'rmtxtHYB9GIGtQkyOwsN',
#     '_score': 6.2939687,
#     '_source': {'original_text': ' The game received generally favorable reviews from video game critics .',
#      'text': 'the game received generally favorable reviews from video game critics',
#      'timestamp': '2020-12-30T17:18:08.269369'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '7ILftXYB9GIGtQkyzh3N',
#     '_score': 6.2939687,
#     '_source': {'original_text': '7 points per game and 20 @.@ 3 rebounds per game .',
#      'text': '7 points per game and 20 @.@ 3 rebounds per game',
#      'timestamp': '2020-12-30T23:58:32.268855'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'AohOtnYB9GIGtQky4-mQ',
#     '_score': 6.2939687,
#     '_source': {'original_text': "> was the game 's referee , his final game before retiring .",
#      'text': "> was the game 's referee his final game before retiring",
#      'timestamp': '2020-12-31T01:59:52.079711'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'GJMDt3YB9GIGtQkyRf0R',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'Video game designer Goichi Suda called it his favourite game . \n',
#      'text': 'video game designer goichi suda called it his favourite game',
#      'timestamp': '2020-12-31T05:16:53.520793'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'FZQKt3YB9GIGtQky3nWq',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'All @-@ Star Game selection for the February 11 , 1996 game .',
#      'text': 'all @-@ star game selection for the february 11 1996 game',
#      'timestamp': '2020-12-31T05:25:11.594074'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'KJc4t3YB9GIGtQkyCzuV',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'The Twins won Game 6 to force a seventh game .',
#      'text': 'the twins won game 6 to force a seventh game',
#      'timestamp': '2020-12-31T06:14:32.212927'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'JaUauHYB9GIGtQky2i44',
#     '_score': 6.2939687,
#     '_source': {'original_text': 'A Video Game Symphony video game music concerts in 2006 .',
#      'text': 'a video game symphony video game music concerts in 2006',
#      'timestamp': '2020-12-31T10:22:16.247820'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'DKL3t3YB9GIGtQkyFPtl',
#     '_score': 6.279004,
#     '_source': {'original_text': 'The Game Critics Awards , selected by journalists and critics , awarded Portal 2 the title of Best PC Game and Best Action / Adventure Game , and nominated the game for Best of Show and Best Console Game .',
#      'text': 'the game critics awards selected by journalists and critics awarded portal 2 the title of best pc game and best action / adventure game and nominated the game for best of show and best console game',
#      'timestamp': '2020-12-31T09:43:11.845384'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'BVyes3YB9GIGtQkyMzsk',
#     '_score': 6.2661276,
#     '_source': {'original_text': 'At the Spike Video Game Awards , Journey won awards as the best PlayStation 3 game , the best indie game , and the game with the best music , and was additionally nominated for game of the year , best downloadable game , best graphics , and best song in a game for " I Was Born For This " .',
#      'text': 'at the spike video game awards journey won awards as the best playstation 3 game the best indie game and the game with the best music and was additionally nominated for game of the year best downloadable game best graphics and best song in a game for i was born for this',
#      'timestamp': '2020-12-30T13:27:38.147723'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tGUmtHYB9GIGtQkyyejv',
#     '_score': 6.2639246,
# ...
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'YnUMtXYB9GIGtQkyfAJq',
#     '_score': 5.9909134,
#     '_source': {'original_text': '6 rebounds per game in leading Porter @-@ Gaud to the state title game .',
#      'text': '6 rebounds per game in leading porter @-@ gaud to the state title game',
#      'timestamp': '2020-12-30T20:07:43.081671'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ynHOtHYB9GIGtQky3iaf',
#     '_score': 5.9909134,
#     '_source': {'original_text': '" I was taking Vicodin twice a game just to get through the game .',
#      'text': 'i was taking vicodin twice a game just to get through the game',
#      'timestamp': '2020-12-30T19:00:24.990423'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'RnHStHYB9GIGtQkywGYQ',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The game jam also brought Molyneux fame within a burgeoning indie game movement .',
#      'text': 'the game jam also brought molyneux fame within a burgeoning indie game movement',
#      'timestamp': '2020-12-30T19:04:39.311728'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'qm-ttHYB9GIGtQkyyxHA',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The Elks game into the game with an undefeated 5 – 0 – 1 record .',
#      'text': 'the elks game into the game with an undefeated 5 – 0 – 1 record',
#      'timestamp': '2020-12-30T18:24:17.471856'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'Y3YftXYB9GIGtQky6ztX',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Parker Brothers also translated the game into a stand @-@ alone tabletop electronic game .',
#      'text': 'parker brothers also translated the game into a stand @-@ alone tabletop electronic game',
#      'timestamp': '2020-12-30T20:28:56.662889'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xXLotHYB9GIGtQkyJ73S',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' The game received " universal acclaim " , according to video game review score aggregator Metacritic .',
#      'text': 'the game received universal acclaim according to video game review score aggregator metacritic',
#      'timestamp': '2020-12-30T19:28:02.130330'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'UGpmtHYB9GIGtQkyzFQk',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' The game received " universal acclaim " , according to video game review score aggregator Metacritic .',
#      'text': 'the game received universal acclaim according to video game review score aggregator metacritic',
#      'timestamp': '2020-12-30T17:06:44.515917'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'dmpmtHYB9GIGtQkyzlRV',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' The game received " universal acclaim " , according to video game review score aggregator Metacritic .',
#      'text': 'the game received universal acclaim according to video game review score aggregator metacritic',
#      'timestamp': '2020-12-30T17:06:45.077052'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '72potHYB9GIGtQky-3kg',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The Channel 4 video game programme GamesMaster gave the game a 70 % rating . \n',
#      'text': 'the channel 4 video game programme gamesmaster gave the game a 70 % rating',
#      'timestamp': '2020-12-30T17:09:07.615936'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '4WpptHYB9GIGtQkyP34u',
#     '_score': 5.9909134,
#     '_source': {'original_text': "Rocksteady originally developed the game 's combat as a full rhythm action game .",
#      'text': "rocksteady originally developed the game 's combat as a full rhythm action game",
#      'timestamp': '2020-12-30T17:09:25.038332'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tn2QtXYB9GIGtQkyqD_7',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Brady Games produced the collectible card game Mortal Kombat Kard Game in 1996 .',
#      'text': 'brady games produced the collectible card game mortal kombat kard game in 1996',
#      'timestamp': '2020-12-30T22:32:05.242804'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'uIt4tnYB9GIGtQky9XyM',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The Game , a platform mobile game featuring a number of South Park characters .',
#      'text': 'the game a platform mobile game featuring a number of south park characters',
#      'timestamp': '2020-12-31T02:45:49.196521'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'AIt8tnYB9GIGtQkyUbHM',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The game was developed using Microsoft XNA , a set of game development tools .',
#      'text': 'the game was developed using microsoft xna a set of game development tools',
#      'timestamp': '2020-12-31T02:49:29.420586'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'A4P7tXYB9GIGtQkyscwe',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Games called the game play " addictive " and praised the two character game play .',
#      'text': 'games called the game play addictive and praised the two character game play',
#      'timestamp': '2020-12-31T00:28:59.678368'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xYQHtnYB9GIGtQkyY4SX',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Game Informer reviewed this game with a 10 / 10 in a classic review .',
#      'text': 'game informer reviewed this game with a 10 / 10 in a classic review',
#      'timestamp': '2020-12-31T00:41:46.262759'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '-oQItnYB9GIGtQkydJTt',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Mike Read , the game \'s producer , summed up the game calling it " human " .',
#      'text': "mike read the game 's producer summed up the game calling it human",
#      'timestamp': '2020-12-31T00:42:56.237261'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ioPvtXYB9GIGtQkyyxE8',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Game three of the Finals in Buffalo was known as the " Fog Game " .',
#      'text': 'game three of the finals in buffalo was known as the fog game',
#      'timestamp': '2020-12-31T00:15:59.931862'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'ZpHhtnYB9GIGtQky-PL9',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' Completion of the game unlocks an emulated version of the original Metroid game .',
#      'text': 'completion of the game unlocks an emulated version of the original metroid game',
#      'timestamp': '2020-12-31T04:40:31.356488'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'PZLntnYB9GIGtQkyHEKm',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'He came on , he changed the game , that is what killed the game .',
#      'text': 'he came on he changed the game that is what killed the game',
#      'timestamp': '2020-12-31T04:46:08.165719'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tZLptnYB9GIGtQkynmpP',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' The game was named the 21st best WiiWare game in 2011 by IGN .',
#      'text': 'the game was named the 21st best wiiware game in 2011 by ign',
#      'timestamp': '2020-12-31T04:48:52.431409'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '6IhLtnYB9GIGtQkyTK-b',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Carrie Gouskos at GameSpot said that the game revitalized the adventure game genre .',
#      'text': 'carrie gouskos at gamespot said that the game revitalized the adventure game genre',
#      'timestamp': '2020-12-31T01:55:56.827332'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '_JYut3YB9GIGtQkylaaj',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'A demo of the game was made available at Tokyo Game Show 2008 .',
#      'text': 'a demo of the game was made available at tokyo game show 2008',
#      'timestamp': '2020-12-31T06:04:12.195416'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'x5DPtnYB9GIGtQkyf86p',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The game was the longest college hockey game played up to that point . \n',
#      'text': 'the game was the longest college hockey game played up to that point',
#      'timestamp': '2020-12-31T04:20:20.649311'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'BJHatnYB9GIGtQkyZ3s8',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'It was awarded Best Game Boy Game of 1993 by Electronic Gaming Monthly .',
#      'text': 'it was awarded best game boy game of 1993 by electronic gaming monthly',
#      'timestamp': '2020-12-31T04:32:15.291765'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xZP-tnYB9GIGtQkyf7K9',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Game Informer called the game " The most skip @-@ worthy entry in the series " .',
#      'text': 'game informer called the game the most skip @-@ worthy entry in the series',
#      'timestamp': '2020-12-31T05:11:40.860683'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'qY6stnYB9GIGtQkyaqRT',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Receiving two major penalties in a game will result in a game misconduct . \n',
#      'text': 'receiving two major penalties in a game will result in a game misconduct',
#      'timestamp': '2020-12-31T03:42:01.427275'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '2o6vtnYB9GIGtQkyFs-S',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' The game primarily consists of four game modes : survival , creative , adventure , and spectator .',
#      'text': 'the game primarily consists of four game modes survival creative adventure and spectator',
#      'timestamp': '2020-12-31T03:44:56.593445'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'xI6ytnYB9GIGtQkyDv6O',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The game is not a shooter , but a point @-@ and @-@ click adventure game . \n',
#      'text': 'the game is not a shooter but a point @-@ and @-@ click adventure game',
#      'timestamp': '2020-12-31T03:48:11.149621'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mJc0t3YB9GIGtQkyuAb2',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Game Informer \'s Lisa Mason said Uru " successfully updated " the adventure game genre .',
#      'text': "game informer 's lisa mason said uru successfully updated the adventure game genre",
#      'timestamp': '2020-12-31T06:10:54.453711'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'OJc5t3YB9GIGtQkygVIa',
#     '_score': 5.9909134,
#     '_source': {'original_text': '; GameSpot labelled it as " the Game Boy Advance game we remember the most " .',
#      'text': 'gamespot labelled it as the game boy advance game we remember the most',
#      'timestamp': '2020-12-31T06:16:07.834115'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'mZc8t3YB9GIGtQkyuIXb',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' Reptile is a video game character from the Mortal Kombat fighting game franchise .',
#      'text': 'reptile is a video game character from the mortal kombat fighting game franchise',
#      'timestamp': '2020-12-31T06:19:38.714973'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'IphOt3YB9GIGtQkyMpjE',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Game Informer initially rated the game a 9 @.@ 75 , but re @-@ rated it',
#      'text': 'game informer initially rated the game a 9 @.@ 75 but re @-@ rated it',
#      'timestamp': '2020-12-31T06:38:44.036015'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'tpyRt3YB9GIGtQkydrzo',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The game served as inspiration for the critically acclaimed adventure game show Knightmare . \n',
#      'text': 'the game served as inspiration for the critically acclaimed adventure game show knightmare',
#      'timestamp': '2020-12-31T07:52:12.391788'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'sZ6vt3YB9GIGtQkyL5Az',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'He personally owns a game cabinet of the 1992 X @-@ Men arcade game . \n',
#      'text': 'he personally owns a game cabinet of the 1992 x @-@ men arcade game',
#      'timestamp': '2020-12-31T08:24:40.115112'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'QZ60t3YB9GIGtQky9Ovo',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The incorporation of heavy metal music into the game also benefited the game .',
#      'text': 'the incorporation of heavy metal music into the game also benefited the game',
#      'timestamp': '2020-12-31T08:30:58.407632'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'VaDQt3YB9GIGtQkySZsy',
#     '_score': 5.9909134,
#     '_source': {'original_text': "The original game 's classical score was considered revolutionary for video game music . \n",
#      'text': "the original game 's classical score was considered revolutionary for video game music",
#      'timestamp': '2020-12-31T09:00:49.458077'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LaLtt3YB9GIGtQkye2Sp',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' Outside of battle , the game contains some strong role @-@ playing video game traditions .',
#      'text': 'outside of battle the game contains some strong role @-@ playing video game traditions',
#      'timestamp': '2020-12-31T09:32:42.921270'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'p6L2t3YB9GIGtQky__mI',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'Portal 2 contains in @-@ game commentary from the game developers , writers , and artists .',
#      'text': 'portal 2 contains in @-@ game commentary from the game developers writers and artists',
#      'timestamp': '2020-12-31T09:43:06.503716'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': '_KP4t3YB9GIGtQky4xf_',
#     '_score': 5.9909134,
#     '_source': {'original_text': "The game also cemented Suda51 's status as an auteur video game director .",
#      'text': "the game also cemented suda51 's status as an auteur video game director",
#      'timestamp': '2020-12-31T09:45:10.526944'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'WqY2uHYB9GIGtQky6edP',
#     '_score': 5.9909134,
#     '_source': {'original_text': ' The game was developed using the Creation Engine , rebuilt specifically for the game .',
#      'text': 'the game was developed using the creation engine rebuilt specifically for the game',
#      'timestamp': '2020-12-31T10:52:55.118716'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'LadBuHYB9GIGtQkyf45w',
#     '_score': 5.9909134,
#     '_source': {'original_text': 'The game received praise , mainly for its audio @-@ visuals , in video game magazines .',
#      'text': 'the game received praise mainly for its audio @-@ visuals in video game magazines',
#      'timestamp': '2020-12-31T11:04:28.911616'}},
#    {'_index': 'concept_embeddings',
#     '_type': '_doc',
#     '_id': 'oVuZs3YB9GIGtQkyJ935',
#     '_score': 5.9727345,
#     '_source': {'original_text': 'Flow became the most downloaded game on the PlayStation Network in 2007 , and won Best Downloadable Game at the Game Developers Choice Awards . \n',
#      'text': 'flow became the most downloaded game on the playstation network in 2007 and won best downloadable game at the game developers choice awards',
#      'timestamp': '2020-12-30T13:22:07.609235'}}]}}

# %% [markdown]
# **Index all phrases**

# %%
MAKE_INDEX = False

if MAKE_INDEX:
    for d in tqdm(train_wikitext_dataset):
        send_to_elasticsearch(d["text"], nlp, es, ES_INDEX)
# Out:
# 100%|██████████| 1801350/1801350 [22:02:28<00:00, 22.70it/s]

# %%
doc = nlp(train_wikitext_dataset[4]["text"])

# %%
for t in list(doc.sents)[0]:
    print(t.text)
# Out:
#
# The
# game
# began
# development
# in
# 2010
# ,
# carrying
# over
# a
# large
# portion
# of
# the
# work
# done
# on
# Valkyria
# Chronicles
# II
# .

# %%
type(list(doc.sents)[0])
# Out:
# spacy.tokens.span.Span

# %%
counter = 0
for d in train_wikitext_dataset:
    text = d["text"]
    doc = nlp(text)
    for sent in doc.sents:
        send_to_solr(sent)
    if counter >= 10:
        break
    counter += 1

#doc = nlp("This is a sentence. This is another sentence.")
#for sent in doc.sents:
#    print(sent.text)
# Out:
#  =
# Valkyria Chronicles III =
#
#  Senjō no Valkyria 3 :
# <unk
# >
# Chronicles ( Japanese : 戦場のヴァルキュリア3 , lit .
# Valkyria of the Battlefield 3 ) , commonly referred to as Valkyria Chronicles III outside Japan , is a tactical role @-@ playing video game developed by Sega and Media.
# Vision for the PlayStation Portable .
# Released in January 2011 in Japan , it is the third game in the Valkyria series .
# Employing the same fusion of tactical and real @-@ time gameplay as its predecessors , the story runs parallel to the first game and follows the " Nameless " , a penal military unit serving the nation of Gallia during the Second Europan War who perform secret black operations and are pitted against the Imperial unit " <unk
# > Raven " .
#
#  The game began development in 2010 , carrying over a large portion of the work done on Valkyria Chronicles II .
# While it retained the standard features of the series , it also underwent multiple adjustments , such as making the game more forgiving for series newcomers .
# Character designer <unk
# >
# Honjou and composer Hitoshi Sakimoto both returned from previous entries , along with Valkyria Chronicles II director Takeshi Ozawa .
# A large team of writers handled the script .
# The game 's opening theme was sung by
# May 'n .
#
#  It met with positive sales in Japan , and was praised by both Japanese and western critics .
# After release , it received downloadable content , along with an expanded edition in November of that year .
# It was also adapted into manga and an original video animation series .
# Due to low sales of Valkyria Chronicles II , Valkyria Chronicles III was not localized , but a fan translation compatible with the game 's expanded edition was released in 2014 .
# Media.
# Vision would return to the franchise with the development of Valkyria : Azure Revolution for the PlayStation 4 .
#
#  =
# =
# Gameplay = =
#
#  As with previous <unk> Chronicles games , Valkyria Chronicles III is a tactical role @-@ playing game where players take control of a military unit and take part in missions against enemy forces .
# Stories are told through comic book @-@ like panels with animated character portraits , with characters speaking partially through voiced speech bubbles and partially through unvoiced text .
# The player progresses through a series of linear missions , gradually unlocked as maps that can be freely scanned through and replayed as they are unlocked .
# The route to each story location on the map varies depending on an individual player 's approach : when one option is selected , the other is sealed off to the player .
# Outside missions , the player characters rest in a camp , where units can be customized and character growth occurs .
# Alongside the main story missions are character @-@ specific sub missions relating to different squad members .
# After the game 's completion , additional episodes are unlocked , some of them having a higher difficulty than those found in the rest of the game .
# There are also love simulation elements related to the game 's two main heroines , although they take a very minor role .
#
#  The game 's battle system , the <unk> system , is carried over directly from <unk> Chronicles .
# During missions , players select each unit using a top @-@ down perspective of the battlefield map : once a character is selected , the player moves the character around the battlefield in third @-@ person .
# A character can only act once per @-@ turn , but characters can be granted multiple turns at the expense of other characters ' turns .
# Each character has a field and distance of movement limited by their Action Gauge .
# Up to nine characters can be assigned to a single mission .
# During gameplay , characters will call out if something happens to them , such as their health points ( HP ) getting low or being knocked out by enemy attacks .
# Each character has specific " Potentials " , skills unique to each character .
# They are divided into " Personal Potential " , which are innate skills that remain unaltered unless otherwise dictated by the story and can either help or impede a character , and " Battle Potentials " , which are grown throughout the game and always grant boons to a character .
# To learn Battle Potentials , each character has a unique " Masters Table " , a grid @-@ based skill table that can be used to acquire and link different skills .
# Characters also have Special Abilities that grant them temporary boosts on the battlefield : Kurt can activate " Direct Command " and move around the battlefield without depleting his Action Point gauge , the character <unk> can shift into her " Valkyria Form " and become invincible , while Imca can target multiple enemy units with her heavy weapon .
